# %% [markdown]
# # **Airbnb Analysis**

# %% [markdown]
# ## **Latar Belakang**
#
# Bangkok, sebagai salah satu kota metropolitan utama di Asia Tenggara, telah menjadi tujuan populer bagi wisatawan internasional dan domestik. Dalam beberapa tahun terakhir, platform seperti Airbnb telah memainkan peran penting dalam mengubah dinamika industri akomodasi di Bangkok.
#
# Airbnb, Inc. adalah perusahaan Amerika yang berbasis di San Francisco dan mengoperasikan marketplace online untuk penginapan jangka pendek dan panjang, serta pengalaman unik. Perusahaan ini berperan sebagai perantara dan mengenakan komisi dari setiap pesanan [Wikipedia](https://en.wikipedia.org/wiki/Airbnb).
#
# Sebuah perusahaan yang bergerak dalam penyewaan properti berencana untuk memperluas bisnisnya dengan menyediakan properti untuk disewakan di Bangkok, Thailand. Properti ini akan dijadikan sebagai listing yang nantinya akan ditawarkan melalui aplikasi Airbnb.perusahaan tersebut berencana untuk menghadirkan properti melalui aplikasi Airbnb. Dalam konteks ini, penting bagi perusahaan untuk memahami dengan mendalam karakteristik properti di Bangkok agar dapat menyesuaikan fitur properti mereka dengan preferensi pasar yang berkembang.
#
# Sebagai perusahaan yang berperan sebagai perantara, pemahaman menyeluruh tentang preferensi dan karakteristik properti Airbnb di berbagai wilayah Bangkok menjadi kunci keberhasilan. Analisis ini akan memberikan wawasan yang diperlukan untuk meningkatkan kualitas layanan, menyesuaikan strategi pemasaran, dan memastikan properti yang ditawarkan dapat memenuhi ekspektasi penyewa Airbnb di kota bangkok

# %% [markdown]
# ## **Pernyataan Masalah**
# Perusahaan ingin mengetahui karakteristik daerah Bangkok dalam penyewaan properti melalui aplikasi Airbnb. Perusahaan mencari karakteristik properti daerah Bangkok agar properti yang nantinya akan disewakan dapat sesuai dengan keinginan pasar dan diminati oleh orang-orang yang akan menyewa. Karakteristik yang dimaksud adalah tipe ruangan, harga dan wilayah mana yang paling diminati agar nanti perusahaan dapat memilih wilayah dan tipe ruangan yang tepat sesuai dengan popularitas penyewaan.
#
# Maka, pertanyaan utama untuk menjawab pernyataan tersebut adalah
#
# 1. Karakteristik Properti Airbnb di Setiap Wilayah:
#     -  Bagaimana karakteristik utama properti Airbnb bervariasi di wilayah Central Bangkok, South Bangkok, North Bangkok, North Thonburi, East Bangkok, dan South Thonburi?
#     - Apakah terdapat preferensi khusus atau tren tertentu dalam fasilitas atau tipe properti di setiap wilayah?
#
# 2. Tipe Properti yang Paling Diminati:
#     - Apa tipe properti (Entire home/apt, Private room, Hotel room, Shared room) yang paling diminati oleh penyewa Airbnb di Bangkok?
#     - Adakah perbedaan signifikan dalam permintaan untuk tipe properti tertentu di berbagai wilayah?
#
# 3. Perbedaan Harga Properti di Berbagai Wilayah:
#     - Bagaimana perbedaan harga properti Airbnb di wilayah Central Bangkok, South Bangkok, North Bangkok, North Thonburi, East Bangkok, dan South Thonburi?
#     - Apakah terdapat faktor tertentu yang secara signifikan mempengaruhi harga properti di setiap wilayah?

# %% [markdown]
# ## **Goals**
#
# 1. Mengidentifikasi Karakteristik Utama Properti:
#     - Menentukan karakteristik utama properti Airbnb yang paling dominan di masing-masing wilayah di Bangkok.
#     - Menganalisis fasilitas dan fitur properti yang paling diunggulkan oleh pemilik dan diminati oleh penyewa di setiap wilayah.
#
# 2. Menganalisis Tren Permintaan Tipe Properti:
#     - Mengidentifikasi tipe properti yang paling diminati oleh penyewa Airbnb di Bangkok secara keseluruhan.
#     - Menilai apakah ada perbedaan signifikan dalam preferensi tipe properti di berbagai wilayah, memberikan wawasan kepada pemilik properti untuk penyesuaian strategis.
#
# 3. Menilai Perbedaan Harga Properti:
#     - Menganalisis perbedaan harga properti Airbnb antara wilayah Central Bangkok, South Bangkok, North Bangkok, North Thonburi, East Bangkok, dan South Thonburi.
#     - Mengidentifikasi faktor-faktor yang mungkin memengaruhi variasi harga dan memberikan panduan kepada pemilik properti dalam menentukan harga yang kompetitif dan sesuai dengan pasar.
#
# 4. Memberikan Rekomendasi Peningkatan Properti:
#     - Menyusun rekomendasi berdasarkan analisis untuk pemilik properti, seperti peningkatan fasilitas atau strategi pemasaran berdasarkan karakteristik wilayah dan tren permintaan.
#     - Memberikan panduan kepada pemilik properti untuk menyesuaikan harga agar lebih bersaing dan meningkatkan daya tarik properti mereka.

# %% [markdown]
# ## **Load Data**
# Untuk menjawab pertanyaan di atas, kita akan menganalisa data peserta yang sudah dikumpulkan oleh perusahaan. Dataset dapat diakses [di sini](https://drive.google.com/drive/folders/1A_KBMRFTS5Mthpp46nulso679ML4ZwTF).

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
data = pd.read_csv('Airbnb Listings Bangkok.csv')
data
# Out:
#        Unnamed: 0                  id  \
# 0               0               27934
# 1               1               27979
# 2               2               28745
# 3               3               35780
# 4               4              941865
# ...           ...                 ...
# 15849       15849  790465040741092826
# 15850       15850  790474503157243541
# 15851       15851  790475335086864240
# 15852       15852  790475546213717328
# 15853       15853  790476492384199044
#
#                                                     name    host_id  \
# 0                        Nice room with superb city view     120437
# 1                         Easy going landlord,easy place     120541
# 2                      modern-style apartment in Bangkok     123784
# 3         Spacious one bedroom at The Kris Condo Bldg. 3     153730
# 4                             Suite Room 3 at MetroPoint     610315
# ...                                                  ...        ...
# ...

# %% [markdown]
# **About Dataset**
#
# Dataset ini berisi informasi mengenai daftar-daftar Airbnb, tuan rumah, serta beberapa metrik penting. Ada 17 kolom di dalam dataset Airbnb, yaitu:
#
# - **Unnamed: 0** : index dari dataset
#
# - **id** : Nomor identifikasi unik untuk Airbnb
#
# - **name** : Nama dari listing
#
# - **host_id** : Nomor identifikasi unik Airbnb untuk tuan rumah/pemilik
#
# - **host_name** : Nama pemilik, biasanya nama depan
#
# - **neighbourhood** : Lingkungan/wilayah tempat listing berada berdasarkan latitude dan longitude
#
# - **latitude** : Menggunakan proyeksi World Geodetic System (WGS84) untuk koordinat lintang
#
# - **longitude** : Menggunakan proyeksi World Geodetic System (WGS84) untuk koordinat bujur
#
# - **room_type** : [Seluruh rumah/apartemen | Kamar pribadi | Kamar bersama | Hotel]
# Semua rumah dikelompokkan ke dalam tiga jenis kamar berikut:
#
#     - "Entire place": Ini merujuk pada penyewaan seluruh unit rumah atau apartemen. Tamu memiliki akses eksklusif ke seluruh ruangan dan fasilitas yang ada di tempat tersebut. Tidak ada orang lain yang tinggal di unit tersebut selama masa menginap tamu.
#
#     - "Private rooms": Kamar pribadi mengacu pada penyewaan satu atau beberapa kamar di dalam suatu unit, tetapi tamu harus berbagi fasilitas umum seperti dapur, ruang tamu, atau kamar mandi dengan pemilik rumah atau mungkin tamu lainnya.
#
#     - "Shared rooms": Kamar bersama berarti tamu akan berbagi ruangan tidur atau ruangan lain dengan tamu lain yang mungkin tidak dikenal sebelumnya. Biasanya, ini adalah pilihan yang lebih ekonomis, dan fasilitas lain seperti kamar mandi dan dapur kemungkinan besar juga bersifat bersama.
#
#     - "Hotel" :mencakup kamar hotel tradisional dengan fasilitas dan layanan hotel standar, suite atau unit yang menyediakan layanan tambahan seperti layanan kamar, serta properti berdesain unik atau tematik yang menawarkan pengalaman menginap yang berbeda.
#
# - **price** : Harga sewa listing dalam mata uang lokal (baht)
#
# - **minimum_nights** : Jumlah minimum masa sewa untuk listing permalam
#
# - **number_of_reviews** : Jumlah ulasan listing, kolom ini juga dapat diasumsikan sebagai jumlah penyewa pada sebuah listing
#
# - **last_review** : Tanggal ulasan terakhir/terbaru
#
# - **reviews_per_month** : Jumlah rata-rata ulasan yang diterima perbulan berdasarkan terakhir mendapat review
#
# - **calculated_host_listings_count** : Jumlah listing yang dimiliki oleh pemilik
#
# - **availability_365** : Ketersediaan listing dalam 365 hari ke depan
#
# - **number_of_reviews_ltm** : Jumlah ulasan yang diterima listing dalam 12 bulan terakhir, kolom ini dapat diasumsikan sebagai jumlah penyewa pada sebuah listing

# %% [markdown]
# <hr>
#
# ## **Data Understanding and Cleaning**
# Sebelum masuk ke dalam analisis, kita perlu mengenal dataset kita lebih jauh dalam tahapan *data understanding*.proses ini diperlukan untuk memahami data-data yang tersedia. Dalam proses ini, diharapkan kita dapat mengetahui anomali-anomali apa saja yang terdapat pada dataset dan selanjutnya akan ditangani dalam tahapan *data cleaning*.

# %%
print(f'Jumlah baris dan kolom di dataset data adalah {data.shape}')
data.info()
# Out:
# Jumlah baris dan kolom di dataset data adalah (15854, 17)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15854 entries, 0 to 15853
# Data columns (total 17 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Unnamed: 0                      15854 non-null  int64
#  1   id                              15854 non-null  int64
#  2   name                            15846 non-null  object
#  3   host_id                         15854 non-null  int64
#  4   host_name                       15853 non-null  object
#  5   neighbourhood                   15854 non-null  object
#  6   latitude                        15854 non-null  float64
#  7   longitude                       15854 non-null  float64
#  8   room_type                       15854 non-null  object
#  9   price                           15854 non-null  int64
#  10  minimum_nights                  15854 non-null  int64
# ...

# %% [markdown]
# <hr>
#
# ## Data Understanding and Cleaning
# Sebelum masuk ke dalam analisis, kita perlu mengenal dataset kita lebih jauh dalam tahapan *data understanding*.proses ini diperlukan untuk memahami data-data yang tersedia. Dalam proses ini, diharapkan kita dapat mengetahui anomali-anomali apa saja yang terdapat pada dataset dan selanjutnya akan ditangani dalam tahapan *data cleaning*.

# %% [markdown]
# **Menampilkan Informasi Terkait Data Frame**

# %%
data.head()
# Out:
#    Unnamed: 0      id                                            name  \
# 0           0   27934                 Nice room with superb city view
# 1           1   27979                  Easy going landlord,easy place
# 2           2   28745               modern-style apartment in Bangkok
# 3           3   35780  Spacious one bedroom at The Kris Condo Bldg. 3
# 4           4  941865                      Suite Room 3 at MetroPoint
#
#    host_id   host_name neighbourhood  latitude  longitude        room_type  \
# 0   120437      Nuttee   Ratchathewi  13.75983  100.54134  Entire home/apt
# 1   120541         Emy       Bang Na  13.66818  100.61674     Private room
# 2   123784  Familyroom     Bang Kapi  13.75232  100.62402     Private room
# 3   153730     Sirilak     Din Daeng  13.78823  100.57256     Private room
# 4   610315       Kasem     Bang Kapi  13.76872  100.63338     Private room
#
#    price  minimum_nights  number_of_reviews last_review  reviews_per_month  \
# ...

# %%
print(f'Jumlah baris dan kolom di dataset data adalah {data.shape}')
data.info()
# Out:
# Jumlah baris dan kolom di dataset data adalah (15854, 17)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15854 entries, 0 to 15853
# Data columns (total 17 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Unnamed: 0                      15854 non-null  int64
#  1   id                              15854 non-null  int64
#  2   name                            15846 non-null  object
#  3   host_id                         15854 non-null  int64
#  4   host_name                       15853 non-null  object
#  5   neighbourhood                   15854 non-null  object
#  6   latitude                        15854 non-null  float64
#  7   longitude                       15854 non-null  float64
#  8   room_type                       15854 non-null  object
#  9   price                           15854 non-null  int64
#  10  minimum_nights                  15854 non-null  int64
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15854 entries, 0 to 15853
# Data columns (total 17 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Unnamed: 0                      15854 non-null  int64
#  1   id                              15854 non-null  int64
#  2   name                            15846 non-null  object
#  3   host_id                         15854 non-null  int64
#  4   host_name                       15853 non-null  object
#  5   neighbourhood                   15854 non-null  object
#  6   latitude                        15854 non-null  float64
#  7   longitude                       15854 non-null  float64
#  8   room_type                       15854 non-null  object
#  9   price                           15854 non-null  int64
#  10  minimum_nights                  15854 non-null  int64
#  11  number_of_reviews               15854 non-null  int64
# ...

# %% [markdown]
# **Unique Values**

# %%
listItem = []
for col in data.columns :
    listItem.append([col, data[col].dtype, data[col].isna().sum(),
                    data[col].nunique(), list(data[col].drop_duplicates().sample(2).values)]);

dfDesc = pd.DataFrame(columns=['dataFeatures', 'dataType', 'null', 'unique', 'uniqueSample'],
                     data=listItem)
print(data.shape)
dfDesc
# Out:
# (15854, 17)
#                       dataFeatures dataType  null  unique  \
# 0                       Unnamed: 0    int64     0   15854
# 1                               id    int64     0   15854
# 2                             name   object     8   14794
# 3                          host_id    int64     0    6659
# 4                        host_name   object     1    5312
# 5                    neighbourhood   object     0      50
# 6                         latitude  float64     0    9606
# 7                        longitude  float64     0   10224
# 8                        room_type   object     0       4
# 9                            price    int64     0    3040
# 10                  minimum_nights    int64     0      86
# 11               number_of_reviews    int64     0     298
# 12                     last_review   object  5790    1669
# 13               reviews_per_month  float64  5790     513
# 14  calculated_host_listings_count    int64     0      50
# ...

# %% [markdown]
# ### **Menghapus kolom `Unnamed: 0`**
#
# Karena kolom ini berisi seperti dengan kolom index, maka kita tidak membutuhkan kolom tersebut.

# %%
# mengahapus kolom Unnamed

data.drop('Unnamed: 0',axis=1,inplace=True)
data.head()
# Out:
#        id                                            name  host_id  \
# 0   27934                 Nice room with superb city view   120437
# 1   27979                  Easy going landlord,easy place   120541
# 2   28745               modern-style apartment in Bangkok   123784
# 3   35780  Spacious one bedroom at The Kris Condo Bldg. 3   153730
# 4  941865                      Suite Room 3 at MetroPoint   610315
#
#     host_name neighbourhood  latitude  longitude        room_type  price  \
# 0      Nuttee   Ratchathewi  13.75983  100.54134  Entire home/apt   1905
# 1         Emy       Bang Na  13.66818  100.61674     Private room   1316
# 2  Familyroom     Bang Kapi  13.75232  100.62402     Private room    800
# 3     Sirilak     Din Daeng  13.78823  100.57256     Private room   1286
# 4       Kasem     Bang Kapi  13.76872  100.63338     Private room   1905
#
#    minimum_nights  number_of_reviews last_review  reviews_per_month  \
# ...

# %% [markdown]
# **Descriptive Statistics**

# %%
display(data.describe(), data.describe(include='object'))
# Out:
#                  id       host_id      latitude     longitude         price  \
# count  1.585400e+04  1.585400e+04  15854.000000  15854.000000  1.585400e+04
# mean   1.579397e+17  1.541058e+08     13.745144    100.559903  3.217704e+03
# std    2.946015e+17  1.318726e+08      0.043040      0.050911  2.497212e+04
# min    2.793400e+04  5.892000e+04     13.527300    100.329550  0.000000e+00
# 25%    2.104509e+07  3.974431e+07     13.720090    100.529690  9.000000e+02
# 50%    3.503734e+07  1.224556e+08     13.738490    100.561415  1.429000e+03
# 75%    5.256154e+07  2.390547e+08     13.759497    100.585150  2.429000e+03
# max    7.908162e+17  4.926659e+08     13.953540    100.923440  1.100000e+06
#
#        minimum_nights  number_of_reviews  reviews_per_month  \
# count    15854.000000       15854.000000       10064.000000
# mean        15.292355          16.654157           0.813145
# std         50.815020          40.613331           1.090196
# ...

# %%
display(data[data['price'] == data['price'].max()])
data[data['price']==0]
# Out:
#                        id                                   name   host_id  \
# 12868  635676064543597376  New 1 bedroom apartment BTS MRT Asoke  12464705
#
#       host_name neighbourhood   latitude   longitude        room_type  \
# 12868     Lucio       Vadhana  13.742186  100.560394  Entire home/apt
#
#          price  minimum_nights  number_of_reviews last_review  \
# 12868  1100000              14                  0         NaN
#
#        reviews_per_month  calculated_host_listings_count  availability_365  \
# 12868                NaN                               1               365
#
#        number_of_reviews_ltm
# 12868                      0
#              id                           name    host_id  \
# 11103  44563108  Somerset Maison Asoke Bangkok  360620448
#
#                    host_name neighbourhood  latitude  longitude   room_type  \
# 11103  Somerset Maison Asoke       Vadhana  13.73815   100.5642  Hotel room
#
# ...

# %%
data[data['minimum_nights'] == 1125]
# Out:
#          id                                               name  host_id  \
# 61  1041976  Long-stay special rate spacious entire floor Siam  5735895
#
#    host_name neighbourhood  latitude  longitude        room_type  price  \
# 61    Pariya   Parthum Wan  13.74814  100.52016  Entire home/apt   2900
#
#     minimum_nights  number_of_reviews last_review  reviews_per_month  \
# 61            1125                295  2021-08-21               2.61
#
#     calculated_host_listings_count  availability_365  number_of_reviews_ltm
# 61                               3                 0                      0

# %% [markdown]
# - `price` : harga termahal untuk listing adalah **1100000** dan termurah adalah **0**.
# - `minimum_night` : minimal menyewa paling besar adalah **1125** malam dan paling sedikit adalah 1 malam.
# - `number_of_reviews` : rata-rata reviews yang diperoleh oleh suatu listing adalah **16**
# - `neighbourhood` : **Vadhana** menjadi wilayah yang sering muncul dalam daftar listing ini.

# %%
import missingno as msno

display(msno.bar(data,figsize=(10,3)))

msno.matrix(data,figsize=(10,3))
# Out:
# <Axes: >
# <Axes: >

# %%
# mengecek missing value
data.isna().sum()
# Out:
# id                                   0
# name                                 8
# host_id                              0
# host_name                            1
# neighbourhood                        0
# latitude                             0
# longitude                            0
# room_type                            0
# price                                0
# minimum_nights                       0
# number_of_reviews                    0
# last_review                       5790
# reviews_per_month                 5790
# calculated_host_listings_count       0
# availability_365                     0
# number_of_reviews_ltm                0
# dtype: int64

# %%
# mengecek missing value dalam bentuk %/persentase
data.isna().sum()/len(data)*100
# Out:
# id                                 0.000000
# name                               0.050460
# host_id                            0.000000
# host_name                          0.006308
# neighbourhood                      0.000000
# latitude                           0.000000
# longitude                          0.000000
# room_type                          0.000000
# price                              0.000000
# minimum_nights                     0.000000
# number_of_reviews                  0.000000
# last_review                       36.520752
# reviews_per_month                 36.520752
# calculated_host_listings_count     0.000000
# availability_365                   0.000000
# number_of_reviews_ltm              0.000000
# dtype: float64

# %% [markdown]
# Terdapat 4 kolom yang memiliki missing value :
# - `name` : 8 missing value atau sebesar **0.05%**
# - `host_name` : 1 missing value atau sebesar **0.01%**
# - `last_review` : 5790 missing value atau sebesar **36.52%**
# - `reviews_per_month` : 5790 missing value atau sebesar **36.52%**

# %% [markdown]
# ### **Menangani missing value pada kolom `name`**

# %%
data[data['name'].isna()]
# Out:
#             id name   host_id        host_name neighbourhood  latitude  \
# 439    4549768  NaN  18852579          Titawan  Phra Khanong  13.69406
# 544    4720818  NaN  24386225           Cherry     Din Daeng  13.77562
# 572    4245018  NaN  22030043        Parichart    Bang Phlat  13.78376
# 669    6148415  NaN  31895202            Chira       Bang Na  13.68276
# 1030   8055144  NaN  42521288          Nantida       Vadhana  13.74126
# 1282  10000742  NaN  51374914  Diamond Bangkok   Ratchathewi  13.75328
# 1594  10710165  NaN  55347997      Khaneungnit       Vadhana  13.71757
# 2075  13142743  NaN  73275200         Pakaphol   Khlong Toei  13.72566
#
#       longitude        room_type  price  minimum_nights  number_of_reviews  \
# 439   100.59619     Private room   1080               5                  0
# 544   100.57346     Private room   1200               1                  0
# 572   100.49821     Private room   1200               1                  0
# ...

# %%
data[data['host_name']=='Pakaphol']
# Out:
#             id                name   host_id host_name neighbourhood  \
# 1981  13400326  Errday Guest House  73275200  Pakaphol   Khlong Toei
# 1982  13400758  Errday Guest House  73275200  Pakaphol   Khlong Toei
# 2075  13142743                 NaN  73275200  Pakaphol   Khlong Toei
#
#       latitude  longitude     room_type  price  minimum_nights  \
# 1981  13.72427  100.56443  Private room    950               1
# 1982  13.72373  100.56415  Private room  36363               1
# 2075  13.72566  100.56416  Private room    850               1
#
#       number_of_reviews last_review  reviews_per_month  \
# 1981                  1  2020-02-19               0.03
# 1982                  0         NaN                NaN
# 2075                  2  2017-12-11               0.03
#
#       calculated_host_listings_count  availability_365  number_of_reviews_ltm
# 1981                               3                 1                      0
# ...

# %% [markdown]
# - Terdapat 8 data kosong pada kolom `name`
# - Terdapat 1 host id yang memiliki `calculated_host_listings_count` yang sama. Kita dapat berasumsi bahwa pada listing tersebut memiliki 2 listing lainnya yang memiliki `name` yang sama.
# - Pada 7 missing value lainnya tidak terdapat persamaan yang dapat digunakan untuk mengisi pada data kosong tersebut.

# %% [markdown]
# **mengisi data pada yang kosong pada host_name : Pakaphol**

# %%
data['name'].iloc[2075] = 'Errday Guest House'
data[data['host_id']==73275200]
# Out:
#             id                name   host_id host_name neighbourhood  \
# 1981  13400326  Errday Guest House  73275200  Pakaphol   Khlong Toei
# 1982  13400758  Errday Guest House  73275200  Pakaphol   Khlong Toei
# 2075  13142743  Errday Guest House  73275200  Pakaphol   Khlong Toei
#
#       latitude  longitude     room_type  price  minimum_nights  \
# 1981  13.72427  100.56443  Private room    950               1
# 1982  13.72373  100.56415  Private room  36363               1
# 2075  13.72566  100.56416  Private room    850               1
#
#       number_of_reviews last_review  reviews_per_month  \
# 1981                  1  2020-02-19               0.03
# 1982                  0         NaN                NaN
# 2075                  2  2017-12-11               0.03
#
#       calculated_host_listings_count  availability_365  number_of_reviews_ltm
# 1981                               3                 1                      0
# ...

# %% [markdown]
# **karena tidak ada data yang mendukung untuk mengisi baris yang `Nan` pada kolom `name` maka baris yang `Nan` Tersebut dihapus**

# %%
# Menghapus baris pada kolom 'name' yang missing value
data.dropna(subset=['name'], inplace= True)

# %% [markdown]
# ### **Missing Value Pada kolom hostname**

# %%
data[data['host_name'].isna()]
# Out:
#             id           name    host_id host_name neighbourhood  latitude  \
# 3571  19682464  Cozy Hideaway  137488762       NaN     Bang Kapi  13.76999
#
#       longitude     room_type  price  minimum_nights  number_of_reviews  \
# 3571  100.63769  Private room   1399               3                  1
#
#      last_review  reviews_per_month  calculated_host_listings_count  \
# 3571  2017-07-29               0.02                               1
#
#       availability_365  number_of_reviews_ltm
# 3571               365                      0

# %% [markdown]
# **karena tidak ada data yang mendukung untuk mengisi baris yang `Nan` pada kolom `host_name` maka baris yang `Nan` Tersebut dihapus**

# %%
data.dropna(subset=['host_name'], inplace= True)

# %%
data.isna().sum()
# Out:
# id                                   0
# name                                 0
# host_id                              0
# host_name                            0
# neighbourhood                        0
# latitude                             0
# longitude                            0
# room_type                            0
# price                                0
# minimum_nights                       0
# number_of_reviews                    0
# last_review                       5784
# reviews_per_month                 5784
# calculated_host_listings_count       0
# availability_365                     0
# number_of_reviews_ltm                0
# dtype: int64

# %%
data[data['price']> 500000]
# Out:
#                        id                                               name  \
# 1239              8880974                 Modern,wifi,5m MRT&2 Shopping Mall
# 1779             11579635                 2 Bedroom,wifi,5mMRT&Shopping Mall
# 4373             22633450                                rm 1 : cozy & comfy
# 4620             23740993       Modern&Luxury apartment,5min to MRT,freeWifi
# 6289             29909847       BTS轻轨线on nut站，全新一房一厅，临Tesco商场市集!New cozy 1BR
# 9345             39858231                1BR cozy condo  close to ONNUT BTS.
# 12300  562972065309061724  3B中文No Guest Service Fee@Nana Asok/Soi11 Night...
# 12868  635676064543597376              New 1 bedroom apartment BTS MRT Asoke
# 15200  766201549677186657      80米轻轨站，空中泳池+健身房，I con siam沙吞河景圈，距离大皇宫4公里，乳胶床垫
#
#          host_id host_name neighbourhood   latitude   longitude  \
# 1239    30803267   Yasmine   Huai Khwang  13.759950  100.569360
# 1779    30803267   Yasmine   Huai Khwang  13.754710  100.565980
# ...

# %% [markdown]
# ### **Missing Value Pada kolom `last_review` & `reviews_per_month`**

# %%
if data[data['last_review'].isna()]['reviews_per_month'].isna().all():
    print("Ya, ketika last review bernilai NaN, reviews per month juga bernilai NaN untuk semua baris")
else:
    print("Tidak, ada beberapa baris di mana last review bernilai NaN tetapi reviews per month tidak bernilai NaN")
# Out:
# Ya, ketika last review bernilai NaN, reviews per month juga bernilai NaN untuk semua baris

# %%
data[['last_review', 'reviews_per_month']].isna().sum()
# Out:
# last_review          5784
# reviews_per_month    5784
# dtype: int64

# %%
data.fillna({'last_review':0}, inplace=True)
data.fillna({'reviews_per_month':0}, inplace=True)

# %% [markdown]
# Terdapat **5784** entri dalam kolom `last_review` & `reviews_per_month` yang kosong. Data kosong kosong karena listing tersebut belum pernah mendapatkan review, sehingga kolom `reviews_per_month` yang berisi rata-rata review perbulan terakhir juga kosong. Maka, dari informasi tersebut kita dapat mengisi data kosong tersebut dengan nilai **0**. Meskipun kolom ini kosong, kita memutuskan untuk mempertahankan data tersebut karena kita tidak dapat berasumsi berdasarkan informasi dari kolom lainnya. Menghapus **5784** baris atau sekitar 36% dar dataset akan berdampak pada hasil analisis secara keseluruhan.

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 15846 entries, 0 to 15853
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              15846 non-null  int64
#  1   name                            15846 non-null  object
#  2   host_id                         15846 non-null  int64
#  3   host_name                       15846 non-null  object
#  4   neighbourhood                   15846 non-null  object
#  5   latitude                        15846 non-null  float64
#  6   longitude                       15846 non-null  float64
#  7   room_type                       15846 non-null  object
#  8   price                           15846 non-null  int64
#  9   minimum_nights                  15846 non-null  int64
#  10  number_of_reviews               15846 non-null  int64
#  11  last_review                     15846 non-null  object
# ...

# %% [markdown]
# ### **Mengubah Dtype `last_review`**
#
# Karena dtype pada kolom ini berupa **object** tetapi isi pada kolom ini berupa tanggal, maka kolom ini akan diubah menjadi **datetime** dtype.

# %%
# Mengubah tipe data kolom 'last_review' menjadi datetime dengan errors='coerce'
data['last_review'] = pd.to_datetime(data['last_review'], errors='coerce')

# %%
# Mendapatkan Tanggal Review Pertama
first_review_date = data['last_review'].min()
print(f"Tanggal Review Pertama: {first_review_date}")

# Mendapatkan Tanggal Review Terakhir
last_review_date = data['last_review'].max()
print(f"Tanggal Review Terakhir: {last_review_date}")
# Out:
# Tanggal Review Pertama: 2012-12-15 00:00:00
# Tanggal Review Terakhir: 2022-12-28 00:00:00

# %% [markdown]
# ### **Data Duplicated**

# %%
# cek duplikat data

data[data.duplicated()]
# Out:
# Empty DataFrame
# Columns: [id, name, host_id, host_name, neighbourhood, latitude, longitude, room_type, price, minimum_nights, number_of_reviews, last_review, reviews_per_month, calculated_host_listings_count, availability_365, number_of_reviews_ltm]
# Index: []

# %% [markdown]
# **Price**

# %%
data['price'].unique()
# Out:
# array([1905, 1316,  800, ..., 2055, 2237, 2298], dtype=int64)

# %% [markdown]
# ### Distribusi data

# %%
cek_data = data[['price', 'minimum_nights', 'number_of_reviews', 'reviews_per_month', 'calculated_host_listings_count', 'availability_365', 'number_of_reviews_ltm']]
cek_data.head()
# Out:
#    price  minimum_nights  number_of_reviews  reviews_per_month  \
# 0   1905               3                 65               0.50
# 1   1316               1                  0               0.00
# 2    800              60                  0               0.00
# 3   1286               7                  2               0.03
# 4   1905               1                  0               0.00
#
#    calculated_host_listings_count  availability_365  number_of_reviews_ltm
# 0                               2               353                      0
# 1                               2               358                      0
# 2                               1               365                      0
# 3                               1               323                      1
# 4                               3               365                      0

# %%
plt.figure(figsize=(15,9))
ax = 1
for kolom in cek_data:
    plt.subplot(3,3, ax)
    sns.boxplot(data=data, x=kolom)
    plt.title(f'Distribusi {kolom}')
    ax += 1

plt.tight_layout()
plt.show()

# %% [markdown]
# Berdasarkan gambar tersebut :
# - Kolom yang tidak memiliki outliers hanya ada pada kolom `availability_365`, sedangkan kolom lainnya memiliki outliers
#
# Tetapi, data yang akan dilihat atau dianalisis lebih lanjut persebaran datanya dan pencarian outliers adalah kolom `price` dan `minimum_nights` karena pada kedua kolom ini pemilik dapat memberikan harga dan minimum menyewa sesuai dengan yang dikehendakinya.

# %% [markdown]
# ### Ourliers pada kolom Price

# %%
sns.boxplot(data = data,x='room_type', y='price')
# Out:
# <Axes: xlabel='room_type', ylabel='price'>

# %% [markdown]
# Terlihat pada _room type_ Entire home/apt, Private room dan Hotel room memiliki outlier price yang cukup tinggi. Sebelum memutuskan untuk dibuang atau tetap disimpan outlier tersebut ,mari kita cek terlebih dahulu.

# %%
data['room_type'].unique()
# Out:
# array(['Entire home/apt', 'Private room', 'Hotel room', 'Shared room'],
#       dtype=object)

# %%
# cek price pada room type Entire home/apt
price_apt = data[data['room_type']=='Entire home/apt'].sort_values(by='price',ascending=False)
display(price_apt.head(),price_apt.tail())
# Out:
#                        id                                               name  \
# 12868  635676064543597376              New 1 bedroom apartment BTS MRT Asoke
# 12300  562972065309061724  3B中文No Guest Service Fee@Nana Asok/Soi11 Night...
# 6289             29909847       BTS轻轨线on nut站，全新一房一厅，临Tesco商场市集!New cozy 1BR
# 1779             11579635                 2 Bedroom,wifi,5mMRT&Shopping Mall
# 4620             23740993       Modern&Luxury apartment,5min to MRT,freeWifi
#
#          host_id host_name neighbourhood   latitude   longitude  \
# 12868   12464705     Lucio       Vadhana  13.742186  100.560394
# 12300  131427125        Jj       Vadhana  13.746660  100.559100
# 6289   210559448      Cora   Khlong Toei  13.703330  100.592470
# 1779    30803267   Yasmine   Huai Khwang  13.754710  100.565980
# 4620    30803267   Yasmine   Huai Khwang  13.760650  100.568980
#
#              room_type    price  minimum_nights  number_of_reviews  \
# ...

# %%
# cek price pada room type Private room
price_privateR = data[data['room_type']=='Private room'].sort_values(by='price',ascending=False)
display(price_privateR.head(),price_privateR.tail())
# Out:
#                        id                                               name  \
# 4373             22633450                                rm 1 : cozy & comfy
# 11885            52940323              🎗𝘾𝙝𝙚𝙬𝙖𝙩𝙝𝙖𝙞 𝙍𝙖𝙢𝙠𝙝𝙖𝙢𝙝𝙖𝙚𝙣𝙜\nBy KhunGrape
# 12792  629653142142561774                    rm 6 : bright morning sunlight.
# 6549             31365769                WH (container, Double bed, 2ppl -F)
# 6760             31364368  WH (Container style, twin bed, 2ppl, citycente...
#
#          host_id  host_name neighbourhood  latitude  longitude     room_type  \
# 4373   117057915       Jeab    Bang Phlat  13.79163  100.49038  Private room
# 11885   99882630   Jiranuch     Bang Kapi  13.76082  100.63366  Private room
# 12792  117057915       Jeab    Bang Phlat  13.79049  100.48816  Private room
# 6549   234881965  Napawadee   Khlong Toei  13.73514  100.55217  Private room
# 6760   234881965  Napawadee   Khlong Toei  13.73505  100.55239  Private room
#
# ...

# %%
# cek price pada room type Hotel room
price_hotel = data[data['room_type']=='Hotel room'].sort_values(by='price',ascending=False)
display(price_hotel.head(),price_hotel.tail())
# Out:
#             id                                            name    host_id  \
# 2668  16139502        Nice Check-in My Hostel (Private 2 beds)   51074483
# 3415  19469957          Stylish 2 Bedroom Apartment in Ekkamai   33550104
# 6281  30329172  European Design In The City Near Shopping Mall  226941360
# 6283  30329222  One Bed In The City of Sukhumvit Near SkyTrain  226941360
# 6282  30329202   Bedroom In Town Central of Sukhumvit Near BTS  226941360
#
#      host_name neighbourhood  latitude  longitude   room_type   price  \
# 2668  Nuttawut   Ratchathewi  13.75113  100.52731  Hotel room  300000
# 3415  Kasamsan       Vadhana  13.73511  100.59068  Hotel room   24390
# 6281   Patawan       Vadhana  13.74248  100.55770  Hotel room   23671
# 6283   Patawan       Vadhana  13.74226  100.55934  Hotel room   23629
# 6282   Patawan       Vadhana  13.74218  100.55802  Hotel room   23029
#
#       minimum_nights  number_of_reviews last_review  reviews_per_month  \
# ...

# %% [markdown]
# Secara garis besar outlier pada price berdasarkan room typenya,
#
# * Masih dapat disimpan karena host boleh saja memberikan harga yang mahal atau murah terhadap properti yang ingin disewakan. Dapat dilihat dari kolom `number_of_reviews` ada yang tidak 0, artinya beberapa guest tidak masalah dengan harganya. Mungkin, fasilitas yang diberikan oleh host memang sesuai dengan harga tersebut.
#
# * Terdapat satu anomali price pada room type Hotel room, ada price yang nilainya 0. Hal tersebut tidak memungkinkan karena tidak masuk akal host menyewakan hotel secara gratis. Data tersebut akan kita drop

# %%
data[data['price']==0]
# Out:
#              id                           name    host_id  \
# 11103  44563108  Somerset Maison Asoke Bangkok  360620448
#
#                    host_name neighbourhood  latitude  longitude   room_type  \
# 11103  Somerset Maison Asoke       Vadhana  13.73815   100.5642  Hotel room
#
#        price  minimum_nights  number_of_reviews last_review  \
# 11103      0               1                  0         NaT
#
#        reviews_per_month  calculated_host_listings_count  availability_365  \
# 11103                0.0                               1                 0
#
#        number_of_reviews_ltm
# 11103                      0

# %% [markdown]
# Listing Airbnb memiliki beberapa informasi wajib, termasuk harga dari properti yang terdaftar.Sebagian besar Tuan Rumah membayar biaya layanan tetap sebesar 3% dari subtotal pemesanan. Subtotal adalah harga per malam ditambah biaya opsional yang Anda kenakan kepada tamu [source informasi](https://www.airbnb.co.id/resources/hosting-homes/a/how-much-does-airbnb-charge-hosts-288). . Oleh karena itu, setiap listing dengan harga sebesar 0 akan dianggap sebagai outliers dalam data dan akan dihapus. Karena hanya ada satu listing yang tidak memiliki harga, maka listing tersebut akan dihapus

# %%
dt_drop = data.drop([11103], axis=0,inplace=True)

# %%
data[data['price']==0]
# Out:
# Empty DataFrame
# Columns: [id, name, host_id, host_name, neighbourhood, latitude, longitude, room_type, price, minimum_nights, number_of_reviews, last_review, reviews_per_month, calculated_host_listings_count, availability_365, number_of_reviews_ltm]
# Index: []

# %%
from scipy.stats import shapiro

# Melakukan uji Shapiro-Wilk pada kolom 'price'
stat, p_value = shapiro(data['price'])

# Menampilkan hasil uji
print(f"Statistik uji Shapiro-Wilk: {stat}")
print(f"P-value: {p_value}")

# Menentukan apakah data terdistribusi normal atau tidak
alpha = 0.05
if p_value > alpha:
    print("Data terdistribusi normal (tidak dapat menolak hipotesis nol)")
else:
    print("Data tidak terdistribusi normal (menolak hipotesis nol)")
# Out:
# Statistik uji Shapiro-Wilk: 0.044427692890167236
# P-value: 0.0
# Data tidak terdistribusi normal (menolak hipotesis nol)

# %% [markdown]
# - karena data tidak terdistribusi normal maka perhitungan akan menggunakan median

# %% [markdown]
# ### Cek Outlier pada kolom `availability_365` dan `minimum_nights`

# %%
data[['availability_365','minimum_nights']].describe()
# Out:
#        availability_365  minimum_nights
# count      15845.000000    15845.000000
# mean         244.333165       15.299905
# std          125.834793       50.828453
# min            0.000000        1.000000
# 25%          138.000000        1.000000
# 50%          309.000000        1.000000
# 75%          360.000000        7.000000
# max          365.000000     1125.000000

# %%
# cek kolom availability_365 yang bernilai 0
data[data['availability_365']==0].sort_values(by='number_of_reviews',ascending=False).head()
# Out:
#             id                                               name   host_id  \
# 623    6033632                   The Mustang Nero/No.2 Black Bird  30963587
# 1499  10500566                 WOW!!! Just 1min walk to BTS OnNut  54134220
# 61     1041976  Long-stay special rate spacious entire floor Siam   5735895
# 3109  17561011                2BR/wifi/1 min to BTS On nut/提供中文服务  44411390
# 1456   9835713    Silom 3 apartment no. 2 (BTS Saladaeng station)  26736483
#
#        host_name neighbourhood  latitude  longitude        room_type  price  \
# 623   Themustang   Khlong Toei  13.71136  100.59217       Hotel room   2000
# 1499   Kittipong  Phra Khanong  13.70482  100.60292  Entire home/apt   1039
# 61        Pariya   Parthum Wan  13.74814  100.52016  Entire home/apt   2900
# 3109        Jeff   Khlong Toei  13.70396  100.59967  Entire home/apt   1800
# 1456           K      Bang Rak  13.72550  100.53019  Entire home/apt    954
#
# ...

# %%
# cek kolom minimum_nights yang lebih dari 1 tahun / 365 hari
data[data['minimum_nights']>365].sort_values(by='number_of_reviews',ascending=False).head()
# Out:
#             id                                               name    host_id  \
# 61     1041976  Long-stay special rate spacious entire floor Siam    5735895
# 1592  10709131                34Fl 2, M Ladprao Condo,MRT & Malls   32398198
# 324    2489610  NEW 65Sqm 2BD 2BR Sukhumvit26 Emquartier Emporium   12743033
# 1200   8801560                 30th floor, 10 min to BTS, Seaview    4517723
# 4194  22059876                                                  C  160989331
#
#       host_name neighbourhood  latitude  longitude        room_type   price  \
# 61       Pariya   Parthum Wan  13.74814  100.52016  Entire home/apt    2900
# 1592  Touchapon    Chatu Chak  13.81699  100.56292  Entire home/apt     760
# 324      Thanan   Khlong Toei  13.72699  100.56988  Entire home/apt    2043
# 1200   Kannicha       Bang Na  13.66417  100.64955  Entire home/apt   35000
# 4194  Annchalee     Thon buri  13.71693  100.48330     Private room  161516
#
# ...

# %% [markdown]
# Secara garis besar outlier pada kolom `availability_365` dan `minimum_nights` :
#
# * Pada kolom `minimum_nights`, terdapat waktu penyewaan yang melebihi 1 tahun atau 365 hari. Hal tersebut memungkinkan terjadi, ketika dilihat dari `number_of_reviews` sudah terdapat reviews pada minimum nights 1125 hari sebanyak  295 reviews. Pada platform Airbnb sendiri kita bisa memesan penginapan lebih dari 1 tahun, dengan pembayarannya perbulan.
# * Pada kolom `availability_365` yang bernilai 0, hal tersebut juga memungkinkan karena terdapat reviews 465 reviews pada availability_365 yang bernilai 0. Dapat diasumsikan ketika data terakhir diambil, properti tersebut sudah di sewa selama 1 tahun lebih.

# %% [markdown]
# Secara garis besar:
# - Kolom `id` dan `host_id` : Kolom `id` berjumlah **15854** no unik dan kolom `host_id` berjumlah **6659** no unik.
# - Kolom `last_review`: berisi tentang kapan terakhir listing tersebut direview, tetapi kita tidak dapat mengetahui review yang diperoleh sebelumnya pada tiap listing. Kolom `last_review` mendapatkan review `pertama` pada tanggal **2012-12-15** dan review `terakhir` pada tanggal **2022-12-28**. Kolom `last_review` tidak terisi apabila pada kolom `number_of_reviews` berisi 0.
# - Kolom `reviews_per_month` : berisi tentang rata-rata jumlah review yang diperoleh dalam sebulan. Kolom `reviews_per_month` tidak terisi apabila pada kolom `number_of_reviews` berisi 0.
# - Kolom `number_of_reviews_ltm` : berisi tentang jumlah review yang diperoleh dalam setahun terakhir. Dataset terakhir diupdate pada tahun 2022, jadi `number_of_reviews_ltm` berisi jumlah review pada tahun **2022**.
# - `price` : harga termahal untuk listing adalah **1100000** dan termurah adalah **0**.
# - `minimum_night` : minimal menyewa paling besar adalah **1125** malam dan paling sedikit adalah 1 malam.
# - `number_of_reviews` : rata-rata reviews yang diperoleh oleh suatu listing adalah **16**
# - `neighbourhood` : **Vadhana** menjadi wilayah yang sering muncul dalam daftar listing ini.
# * *missing value* di kolom `last_review`, `reviews_per_month` memiliki proporsi yang cukup tinggi (>10%), dengan missing value di kedua kolom mencapai
# 36.5%.
#
# * *missing value* di kolom `company_size` dan `company_type` memiliki sebaran yang terlihat berkaitan, jika data di `company_size` kosong, maka kemungkinan besar data di `company_type` juga kosong.
#
# Anomali pada kolom :
# - Kolom `Unnamed:0`: berisi serupa dengan index, maka kita tidak memerlukan kolom ini.

# %% [markdown]
# ## **Data Preparation**

# %% [markdown]
# ### **A. Menambah Kolom Baru Pada Dataset**

# %% [markdown]
# ### **Menambah Kolom `region`**

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 15845 entries, 0 to 15853
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              15845 non-null  int64
#  1   name                            15845 non-null  object
#  2   host_id                         15845 non-null  int64
#  3   host_name                       15845 non-null  object
#  4   neighbourhood                   15845 non-null  object
#  5   latitude                        15845 non-null  float64
#  6   longitude                       15845 non-null  float64
#  7   room_type                       15845 non-null  object
#  8   price                           15845 non-null  int64
#  9   minimum_nights                  15845 non-null  int64
#  10  number_of_reviews               15845 non-null  int64
#  11  last_review                     10062 non-null  datetime64[ns]
# ...

# %%
data['neighbourhood'].unique()
# Out:
# array(['Ratchathewi', 'Bang Na', 'Bang Kapi', 'Din Daeng',
#        'Bang Kho laen', 'Rat Burana', 'Chatu Chak', 'Khlong San',
#        'Bang Rak', 'Phaya Thai', 'Sathon', 'Khlong Toei', 'Vadhana',
#        'Sai Mai', 'Lat Krabang', 'Bangkok Yai', 'Wang Thong Lang',
#        'Huai Khwang', 'Phasi Charoen', 'Bang Sue', 'Nong Chok',
#        'Phra Khanong', 'Thawi Watthana', 'Parthum Wan', 'Pra Wet',
#        'Phra Nakhon', 'Thon buri', 'Yan na wa', 'Suanluang', 'Don Mueang',
#        'Dusit', 'Lak Si', 'Samphanthawong', 'Bueng Kum', 'Bang Phlat',
#        'Saphan Sung', 'Min Buri', 'Khan Na Yao', 'Khlong Sam Wa',
#        'Bang Khen', 'Lat Phrao', 'Chom Thong', 'Bangkok Noi',
#        'Pom Prap Sattru Phai', 'Nong Khaem', 'Thung khru', 'Bang Khae',
#        'Bang Khun thain', 'Taling Chan', 'Bang Bon'], dtype=object)

# %% [markdown]
# ### **Membuat kolom Region**

# %% [markdown]
# - Terdapat 50 neighbourhood yang unik, sesuai dengan informasi yang ditemukan di [wikipedia](https://id.wikipedia.org/wiki/Daftar_distrik_Bangkok) dan [alamy](https://www.alamy.com/bangkok-administrative-and-political-map-with-flag-image328835295.html).
# - Kota Bangkok berdasarkan [researchgate](https://www.researchgate.net/figure/Map-of-Bangkok-Thailand-indicating-the-location-of-the-investigated-districts-as-well_fig1_358916974) dapat dibagi menjadi 6 kelompok wilayah ('Central Bangkok', 'South Bangkok', 'North Bangkok', 'East Bangkok', 'North Thonburi' dan 'South Thonburi') sebagaimana dijelaskan dalam sumber seperti ResearchGate. Oleh karena itu, pembuatan kolom baru akan dilakukan untuk mempermudah tahap analisis berdasarkan kelompok wilayah ini..

# %%
def bangkok_area(x):
    if x in ['Phra Nakhon', 'Samphanthawong', 'Pom Prap Sattru Phai', 'Dusit', 'Ratchathewi', 'Phaya Thai', 'Din Daeng', 'Huai Khwang', 'Wang Thong Lang'] :
        return 'Central Bangkok'
    elif x in ['Bang Kho laen', 'Yan na wa', 'Sathon', 'Bang Rak', 'Parthum Wan', 'Khlong Toei', 'Suanluang', 'Phra Khanong', 'Bang Na', 'Vadhana'] :
        return 'South Bangkok'
    elif x in ['Bang Sue', 'Chatu Chak', 'Lat Phrao', 'Lak Si', 'Sai Mai', 'Don Mueang', 'Bang Khen'] :
        return 'North Bangkok'
    elif x in ['Nong Khaem', 'Bang Khae', 'Phasi Charoen', 'Bang Bon', 'Bang Khun thain', 'Thung khru', 'Rat Burana'] :
        return 'South Thonburi'
    elif x in ['Thawi Watthana', 'Taling Chan', 'Bangkok Noi', 'Bang Phlat', 'Bangkok Yai', 'Thon buri', 'Khlong San', 'Chom Thong'] :
        return 'North Thonburi'
    elif x in ['Khlong Sam Wa', 'Nong Chok', 'Min Buri', 'Lat Krabang', 'Khan Na Yao', 'Bueng Kum', 'Saphan Sung', 'Pra Wet', 'Bang Kapi'] :
        return 'East Bangkok'
    else:
        return x

# %%
data['region'] = data['neighbourhood'].apply(bangkok_area)

display(data.head(), data.shape)
# Out:
#        id                                            name  host_id  \
# 0   27934                 Nice room with superb city view   120437
# 1   27979                  Easy going landlord,easy place   120541
# 2   28745               modern-style apartment in Bangkok   123784
# 3   35780  Spacious one bedroom at The Kris Condo Bldg. 3   153730
# 4  941865                      Suite Room 3 at MetroPoint   610315
#
#     host_name neighbourhood  latitude  longitude        room_type  price  \
# 0      Nuttee   Ratchathewi  13.75983  100.54134  Entire home/apt   1905
# 1         Emy       Bang Na  13.66818  100.61674     Private room   1316
# 2  Familyroom     Bang Kapi  13.75232  100.62402     Private room    800
# 3     Sirilak     Din Daeng  13.78823  100.57256     Private room   1286
# 4       Kasem     Bang Kapi  13.76872  100.63338     Private room   1905
#
#    minimum_nights  number_of_reviews last_review  reviews_per_month  \
# ...

# %% [markdown]
# ### **Membuat DataFrame Baru**
# Untuk memudahkan proses analisis diperlukan pembuatan DataFrame baru

# %%
# Membuat DataFrame dengan 'last_review' dari tahun 2012 sampai 2022
dt_last_review = data.dropna(subset=['last_review'])
dt_last_review
# Out:
#                        id                                               name  \
# 0                   27934                    Nice room with superb city view
# 3                   35780     Spacious one bedroom at The Kris Condo Bldg. 3
# 5                 1704776                     NEw Pro!!  Bungalow Bkk Centre
# 6                   48736                    Condo with Chaopraya River View
# 8                 1744248                 Batcave, Pool view, near Chatuchak
# ...                   ...                                                ...
# 15712  785741287659406453                        ใจกลางเมืองติดห้างไอคอนสยาม
# 15728  785976692600131294      1br/Free pool&gym/WIFI-Asok/SukhumvitBTS! 2PP
# 15743  786248090308669514                 Vibrant Luxe 2 Bedroom | Thong Lor
# 15744  786318268883527580                 Vibrant Luxe 2 Bedroom | Thong Lor
# 15796  788841933134248110  Stunning river view in the heart of BKK 5min/t...
#
# ...

# %% [markdown]
# - DataFrame (`df_last_review`) berisi listing yang mempunyai `last_review` antara tahun 2012 Desember hingga 2022 Desember.
# - DataFrame berjumlah **10062** baris dan **17** kolom

# %%
data
# Out:
#                        id                                               name  \
# 0                   27934                    Nice room with superb city view
# 1                   27979                     Easy going landlord,easy place
# 2                   28745                  modern-style apartment in Bangkok
# 3                   35780     Spacious one bedroom at The Kris Condo Bldg. 3
# 4                  941865                         Suite Room 3 at MetroPoint
# ...                   ...                                                ...
# 15849  790465040741092826      素坤逸核心两房公寓42楼，靠近BTSon nut/无边天际泳池观赏曼谷夜景/出门当地美食街
# 15850  790474503157243541  Euro LuxuryHotel PratunamMKt TripleBdNrShoping...
# 15851  790475335086864240  Euro LuxuryHotel PratunamMKt TwinBedNrShopingArea
# 15852  790475546213717328  Euro LuxuryHotel PratunamMKt TwinBedNrShopingArea
# 15853  790476492384199044  Euro LuxuryHotel PratunamMKt TwinBedNrShopingArea
#
# ...

# %% [markdown]
# ### Clean Data

# %%
# # data yang sudah dibersihkan disimpan menjadi file .csv
data.to_csv('Airbnb Listings Bangkok Clean.csv', index=False)

# %%
print(f'Jumlah baris dan kolom di dataset airbnb adalah {data.shape}')
# Out:
# Jumlah baris dan kolom di dataset airbnb adalah (15845, 17)

# %% [markdown]
# **Total Data yang sudah clean ada 15845 data**

# %% [markdown]
# ## **Data Analysis**
#
# Kita sudah melakukan tahap _data cleaning_. Sekarang, kita bisa mulai melakukan analisis untuk menjawab rumusan masalah.
#
# Dengan menganalisis region berdasarkan dengan setiap faktornya, kita dapat memperoleh insight statistik yang berguna untuk tim marketing nantinya.

# %%
# Membuat korelasi menggunakan metode 'spearman'
df_corr = data[['price', 'minimum_nights', 'number_of_reviews', 'reviews_per_month', 'calculated_host_listings_count', 'availability_365', 'number_of_reviews_ltm']].corr(method='spearman')

# Membuat matriks yang akan digunakan
matriks = np.triu(df_corr)

# Memvisualisasikan korelasi dalam bentuk 'heatmap'
plt.figure(figsize=(15,5))
sns.heatmap(data=df_corr, annot=True, cmap='coolwarm', center=0, mask=matriks, fmt='.2f')
plt.xticks(rotation= 45)
plt.title("Korelasi Antar Kolom Numerikal")
plt.show()

# %% [markdown]
# ### Insight :
# - Terdapat 3 Korelasi yang masuk dalam kategori kuat positif (0.7 - 1). Maka, semakin tinggi nilai suatu data maka semakin tinggi kolom lainnya.
# - kolom `reviews_per_month` berhubungan dengan `number_of_reviews`
# - kolom `number_of_reviews_ltm` berhubungan dengan `number_of_reviews`
# - kolom `number_of_reviews_ltm` berhubungan dengan `reviews_per_month`

# %% [markdown]
# ## **Analisa Berdasarkan `region`**

# %% [markdown]
# **Proporsi Jumlah Listing Berdasarkan Region**

# %%
# Create a new DataFrame with counts of listings per region
region_counts = data['region'].value_counts().reset_index()
region_counts.columns = ['region', 'listings_count']

# Create a pivot table based on the count of listings per region
pivot_table_region = region_counts.pivot_table(
    index=['region'],
    values='listings_count',
    aggfunc='sum'
).sort_values('listings_count', ascending=False).reset_index()

# Display the pivot table
print("\n jumlah Listings per Region:")
print(pivot_table_region)
# Out:
#  jumlah Listings per Region:
#             region  listings_count
# 0    South Bangkok            8074
# 1  Central Bangkok            4150
# 2    North Bangkok            1304
# 3   North Thonburi            1133
# 4     East Bangkok             826
# 5   South Thonburi             358

# %%
plt.figure(figsize=(16, 8))
ax = sns.barplot(x='region', y='listings_count', data=pivot_table_region)
ax.set_title('Jumlah Listing berdasarkan Region')
ax.set_xlabel('Region')
ax.set_ylabel('Jumlah Listings')

# Menambahkan label di atas setiap bar
for p in ax.patches:
    height = p.get_height()
    ax.text(p.get_x() + p.get_width() / 2., height + 5, f'{int(height)}', ha='center', va='bottom')

# Rotate x-axis labels for better visibility
plt.xticks(rotation=45, ha='right')

# Display the chart
plt.show()

# %% [markdown]
# **Insight**
#
# - South Bangkok: South Bangkok memiliki jumlah listings yang signifikan, yaitu 8074. Ini menunjukkan bahwa wilayah ini menjadi fokus utama untuk menyewakan properti, mungkin karena popularitasnya di kalangan pengunjung.
#
# - Central Bangkok di Posisi Kedua: Central Bangkok menempati posisi kedua dengan 4150 listings. Ini juga merupakan jumlah yang signifikan, dan bersama dengan South Bangkok, menunjukkan bahwa pusat kota menjadi area yang sangat dicari untuk akomodasi.
#
# - Perbedaan yang Signifikan: Perbedaan jumlah listings antara South Bangkok, Central Bangkok, dan wilayah lainnya cukup besar. Hal ini mungkin mencerminkan perbedaan dalam permintaan dan penawaran akomodasi di setiap wilayah.
#
# - Potensi Peluang Investasi: Melihat wilayah-wilayah dengan jumlah listings yang lebih rendah seperti South Thonburi dan East Bangkok, mungkin terdapat peluang investasi atau pengembangan lebih lanjut di wilayah-wilayah ini.

# %% [markdown]
# # Analisa Berdasarkan Neighbourhood

# %%
# Menghitung jumlah listing berdasarkan neighbourhood 
jumlah_per_neighbourhood = data.groupby(['neighbourhood']).size().reset_index(name='jumlah_listing')

# Mengambil 5 neighbourhood teratas
top_5_neighbourhood = jumlah_per_neighbourhood.sort_values(by='jumlah_listing', ascending=False).head(5)

# Mencetak data
print(top_5_neighbourhood)
# Out:
#    neighbourhood  jumlah_listing
# 47       Vadhana            2150
# 22   Khlong Toei            2097
# 18   Huai Khwang            1125
# 37   Ratchathewi            1113
# 8       Bang Rak             827

# %% [markdown]
# **insight**
#
# - Neighbourhood Vadhana dan Khlong Toei di South Bangkok memiliki jumlah listing yang tinggi, masing-masing sebanyak `2150` dan `2097`. Ini menunjukkan bahwa beberapa neighbourhood di South Bangkok lebih populer untuk disewakan dibandingkan dengan neighbourhood di wilayah lain.
#
# - Dua neighbourhood, yaitu Huai Khwang dan Ratchathewi, mendominasi di Central Bangkok dengan jumlah listing berturut-turut 1125 dan 1113. Ini menunjukkan bahwa di Central Bangkok, konsentrasi listing tertinggi terdapat di neighbourhood ini.
#
# - Distribusi Listing yang Tidak Merata: Jumlah listing yang signifikan di beberapa neighbourhood dapat menunjukkan distribusi penawaran akomodasi yang tidak merata di seluruh wilayah kota.
#
# - Bang Rak di South Bangkok: Neighbourhood Bang Rak di South Bangkok juga memiliki jumlah listing yang cukup besar `827`. Ini dapat menunjukkan bahwa neighbourhood ini menarik perhatian penyewa dan memiliki beragam opsi akomodasi.

# %%
colors = ['blue', 'coral', 'green', 'grey', 'pink', 'red']

plt.figure(figsize=(12, 6))
plt.bar(top_5_neighbourhood['neighbourhood'], top_5_neighbourhood['jumlah_listing'], color=colors)
plt.title('Top 5 Lingkungan berdasarkan Jumlah listing')
plt.xlabel('Lingkungan (Neighbourhood)')
plt.ylabel('Jumlah Properti')
plt.xticks(rotation=45, ha='right')

# Menambahkan label harga di atas setiap bar
for i, v in enumerate(top_5_neighbourhood['jumlah_listing']):
    plt.text(i, v + 10, str(v), ha='center', va='bottom', color='black')

plt.show()

# %% [markdown]
# Berdasarkan grafik diatas dapat diketahui bahwa South Bangkok memiliki jumlah listing terbanyak dibandingkan region lainnya, yaitu sekitar 51%. Dari data jumlah listing properti Airbnb di Bangkok, South Bangkok, terutama Vadhana dan Khlong Toei, mendominasi dengan masing-masing 2150 dan 2097 listing. Central Bangkok juga melalui Huai Khwang dan Ratchathewi, dengan masing-masing menyumbang 1125 dan 1113 listing. Keseluruhan, South Bangkok, dengan dominasi Vadhana dan Khlong Toei, menjadi fokus utama dengan tingginya minat penyewa terhadap wilayah tersebut di platform Airbnb. Berikut merupakan karakteristik per region berdasarkan riset:
#
# - **center bangkok** : Central Bangkok memegang peranan vital sebagai pusat sejarah, budaya, dan bisnis di Bangkok. Daerah ini dikenal sebagai rumah dari beberapa landmark ikonik seperti Grand Palace, yang menjadi pusat sejarah dan kebudayaan, serta berbagai istana megah termasuk Dusit. Ratchathewi, dengan distrik perbelanjaannya yang ramai seperti Pratunam dan Siam Square, menambahkan nuansa komersial yang sibuk. Keberagaman sejarah, arsitektur tradisional, dan warisan budaya menjadi ciri khas Central Bangkok..
#
#
# - **South Bangkok** : South Bangkok menonjol sebagai pusat aktivitas bisnis, perbelanjaan, dan hiburan di kota. Distrik seperti Sathon dan Bang Rak menjadi pusat kegiatan komersial dengan kepadatan tinggi. Vadhana dan Khlong Toei, sebagai pusat bisnis utama, menambahkan intensitas ekonomi. Seiring dengan keberagaman dalam pilihan hiburan, South Bangkok menjadi destinasi yang dinamis dan penuh energi.
#
# - **north Bangkok** : North Bangkok menampilkan suasana yang lebih tenang dengan fokus pada perumahan dan pendidikan. Daerah ini mencakup wilayah seperti Chatuchak yang dikenal dengan pasar weekendnya, menciptakan lingkungan perumahan yang nyaman dan ramah keluarga. Bang Sue dan Lak Si, dengan institusi pendidikan dan ruang terbuka, menambahkan nilai pendidikan dan keasrian alam.
#
# - **South Thonburi** : South Thonburi, yang terletak di seberang Sungai Chao Phraya, menawarkan kombinasi antara kesejukan lingkungan dan sedikit aktivitas industri. Daerah ini, seperti Bang Khae dan Phasi Charoen, menciptakan harmoni antara perumahan dan keberlanjutan lingkungan. South Thonburi menjadi tempat yang tenang dan nyaman untuk tinggal.
#
# - **North Thonburi** : North Thonburi adalah wilayah yang menyuguhkan keindahan alam dan warisan budaya. Daerah ini memiliki taman dan kebun yang luas, seperti Taling Chan yang terkenal dengan kanal dan pertanian. Distrik seperti Khlong San menawarkan pemandangan sungai yang indah, sementara Bangkok Noi dan Thonburi memberikan nuansa tradisional yang memikat.
#
# - **East Bangkok** : East Bangkok menciptakan perpaduan antara kehidupan perkotaan yang modern dengan lingkungan perumahan yang beragam. Daerah ini, termasuk Lat Krabang yang dekat dengan Bandara Suvarnabhumi, menjadi pilihan bagi mereka yang mencari aksesibilitas dan kenyamanan. Bang Kapi, dengan Universitas Ramkhamhaengnya, menambahkan nuansa pendidikan dan kehidupan perkotaan yang dinamis.

# %% [markdown]
# ## **Analisa Berdasarkan Room type**

# %% [markdown]
# #### **`price` berdasarkan `room type`**

# %%
# Membuat tabel region dengan median harganya
dt_price = data.pivot_table(
    index=['room_type'],
    values='price',
    aggfunc='median'
).sort_values('price', ascending=False).reset_index()

# Menampilkan tabel
print(dt_price)
# Out:
#          room_type   price
# 0       Hotel room  1700.0
# 1  Entire home/apt  1536.0
# 2     Private room  1213.0
# 3      Shared room   500.0

# %%
colors = ['blue', 'coral', 'green', 'grey', 'pink', 'red']

ax = sns.barplot(data=dt_price, x='room_type', y='price', estimator=sum, palette=colors)
plt.title('Jumlah Harga Berdasarkan Room Type')

plt.xlabel('Room Type')
plt.ylabel('Harga (dalam baht)')

# Menambahkan label harga di atas setiap bar
for i, v in enumerate(dt_price['price']):
    plt.text(i, v + 10, f'{int(v)} Baht', ha='center', va='bottom', color='black')

plt.show()

# %% [markdown]
# Berdasarkan grafik tersebut:
# - Berdasarkan data harga properti Airbnb di Bangkok berdasarkan tipe kamar, dapat disimpulkan bahwa tipe kamar "Hotel room" memiliki harga median tertinggi, yakni sekitar 1700 Baht, diikuti oleh "Entire home/apt" dengan median harga sekitar 1536 Baht. Sementara itu, "Private room" memiliki median harga sekitar 1213 Baht, dan "Shared room" memiliki median harga terendah, yaitu 500 Baht. Analisis ini mengindikasikan bahwa properti dengan tipe kamar hotel memiliki kecenderungan untuk memiliki harga yang lebih tinggi, mungkin karena fasilitas dan layanan yang lebih lengkap. Sebaliknya, tipe kamar yang melibatkan berbagi ruangan, seperti "Shared room," cenderung memiliki harga yang lebih terjangkau.

# %%
# Membuat tabel region berdasarkan tipe ruangan dan harganya
d_price = data.pivot_table(
    index= ['region', 'room_type'],
    values= 'price',
    aggfunc= 'median'
).reset_index().sort_values('region',ascending=True)
print('region berdasarkan tipe ruangan dan harganya')
d_price
# Out:
# region berdasarkan tipe ruangan dan harganya
#              region        room_type   price
# 0   Central Bangkok  Entire home/apt  1514.0
# 1   Central Bangkok       Hotel room  1481.0
# 2   Central Bangkok     Private room  1318.0
# 3   Central Bangkok      Shared room   500.0
# 4      East Bangkok  Entire home/apt  1122.0
# 5      East Bangkok       Hotel room  1288.0
# 6      East Bangkok     Private room   899.5
# 7      East Bangkok      Shared room   390.0
# 10    North Bangkok     Private room   950.0
# 11    North Bangkok      Shared room   586.5
# 8     North Bangkok  Entire home/apt  1000.0
# 9     North Bangkok       Hotel room   977.5
# 12   North Thonburi  Entire home/apt  1300.0
# 13   North Thonburi       Hotel room  1800.0
# 14   North Thonburi     Private room  1100.0
# 15   North Thonburi      Shared room   440.0
# 16    South Bangkok  Entire home/apt  1712.0
# 17    South Bangkok       Hotel room  1899.0
# 18    South Bangkok     Private room  1430.0
# ...

# %%
# Membuat plot
plt.figure(figsize=(13, 7))
ax = sns.barplot(data=d_price, x='region', y='price', hue='room_type', estimator=sum)

# Menambahkan label di atas setiap bar (jika tinggi bar lebih besar dari 0)
for p in ax.patches:
    height = p.get_height()
    if height > 0:
        ax.text(p.get_x() + p.get_width() / 2., height + 5, f'{int(height)}', ha='center', va='bottom')

plt.title('Harga per Tipe Ruangan Berdasarkan Region')
plt.xlabel('Region')
plt.ylabel('Harga')
plt.legend(title='Tipe Ruangan')

plt.show()

# %% [markdown]
# - terlihat variasi harga yang signifikan antar tipe ruangan di Central Bangkok, dengan "Entire home/apt" memiliki harga tertinggi sekitar 1514 THB, sedangkan "Shared room" lebih terjangkau dengan harga 500 THB. East Bangkok menampilkan harga tertinggi untuk "Entire home/apt" sekitar 1122 THB, sementara "Shared room" lebih terjangkau dengan harga 390 THB. North Bangkok menunjukkan variasi harga yang seragam di semua tipe ruangan, sedangkan North Thonburi menonjol dengan harga "Hotel room" mencapai 1800 THB. South Bangkok menampilkan harga tertinggi, terutama untuk "Hotel room" yang mencapai 1899 THB. South Thonburi menunjukkan variasi harga moderat. Kesimpulannya, perbedaan harga ini mencerminkan preferensi dan permintaan pasar yang beragam di setiap region di Bangkok.
#
#
# - Perbedaan harga antar region dan tipe ruangan di Bangkok dapat dipengaruhi oleh sejumlah faktor. Central Bangkok, sebagai pusat kota dan pusat bisnis, cenderung memiliki harga lebih tinggi, terutama untuk tipe ruangan yang menawarkan privasi dan kenyamanan maksimal seperti "Entire home/apt" dan "Hotel room".
#
# - `room_type` dengan tipe `Entire home/apt` dan `Hotel room` merupakan tipe ruangan yang menempati harga termahal pada posisi 1 atau 2 pada keseluruhan region.

# %% [markdown]
# ### Jumlah Review by room type

# %% [markdown]
# > Jumlah Review Berdasarkan Tipe kamar(Room Type)

# %%
# Membuat tabel room type berdasarkan jumlah review
dt_reviews = data.pivot_table(
    index=['room_type'],
    values='number_of_reviews',
    aggfunc='sum'
).sort_values('number_of_reviews', ascending=False).reset_index()

# Menampilkan tabel
print('room type berdasarkan jumlah review')
print(dt_reviews)
# Out:
# room type berdasarkan jumlah review
#          room_type  number_of_reviews
# 0  Entire home/apt             197943
# 1     Private room              50703
# 2       Hotel room              12700
# 3      Shared room               2682

# %%
# Pengaturan gaya seaborn
sns.set(style="whitegrid")

# Membuat bar plot
plt.figure(figsize=(10, 6))
ax = sns.barplot(x='room_type', y='number_of_reviews', data=dt_reviews, palette='viridis')
ax.set_title('Jumlah Review Berdasarkan Tipe Kamar', fontsize=16)
ax.set_xlabel('Tipe Kamar', fontsize=14)
ax.set_ylabel('Jumlah Review', fontsize=14)

# Menambahkan label di atas setiap bar
for p in ax.patches:
    ax.annotate(f'{p.get_height()}', (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='center', xytext=(0, 10), textcoords='offset points', fontsize=12)

plt.show()

# %% [markdown]
# # **Analisa Berdasarkan Review 12 bulan terakhir**

# %% [markdown]
# > Jumlah Review 12 Bulan Terakhir Berdasarkan Region

# %%
region_reviews = data.groupby('region')['number_of_reviews_ltm'].sum().reset_index()
region_reviews = region_reviews.sort_values(by='number_of_reviews_ltm', ascending=False)

print('jumlah review 12 bulan terakhir berdasarkan region')
print(region_reviews)
# Out:
# jumlah review 12 bulan terakhir berdasarkan region
#             region  number_of_reviews_ltm
# 4    South Bangkok                  35154
# 0  Central Bangkok                  13747
# 2    North Bangkok                   2505
# 3   North Thonburi                   2059
# 1     East Bangkok                   1346
# 5   South Thonburi                    385

# %%
# Definisi warna untuk setiap region
colors = ['orange', 'yellow', 'cyan', 'magenta', 'pink']

# Membuat bar plot dengan Seaborn
plt.figure(figsize=(12, 8))
ax = sns.barplot(x=region_reviews['region'], y=region_reviews['number_of_reviews_ltm'], palette=colors)
ax.set(xlabel='Region', ylabel='Jumlah Review (12 Bulan Terakhir)',
       title='Jumlah Review dalam 12 bulan terakhir berdasarkan Region')

# Menambahkan label di atas setiap bar
for p in ax.patches:
    ax.annotate(f'{p.get_height()}', (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='center', xytext=(0, 10), textcoords='offset points', fontsize=12)

plt.show()

# %% [markdown]
# Top 5 Neighbourhood berdasarkan Review 12 bulan terakhir

# %%
top_neighborhoods_review_ltm = data.groupby('neighbourhood')['number_of_reviews_ltm'].sum().reset_index()
top_neighborhoods_review_ltm = top_neighborhoods_review_ltm.sort_values(by='number_of_reviews_ltm', ascending=False).head(5)

print('Top 5 jumlah review 12 bulan terakhir berdasarkan neighbourood')
top_neighborhoods_review_ltm
# Out:
# Top 5 jumlah review 12 bulan terakhir berdasarkan neighbourood
#    neighbourhood  number_of_reviews_ltm
# 22   Khlong Toei                  13601
# 47       Vadhana                   9709
# 37   Ratchathewi                   4455
# 8       Bang Rak                   3420
# 41        Sathon                   3232

# %%
colors = ['orange', 'yellow', 'cyan', 'magenta', 'pink']

# Create a figure and axes
plt.figure(figsize=(10, 5))
ax = plt.bar(top_neighborhoods_review_ltm['neighbourhood'], top_neighborhoods_review_ltm['number_of_reviews_ltm'], color=colors)

# Add text labels on top of the bars
for p in ax.patches:
    height = p.get_height()
    if height > 0:
        plt.text(p.get_x() + p.get_width() / 2., height + 5, f'{int(height)}', ha='center', va='bottom')

plt.xlabel('Neighborhood')
plt.ylabel('Number of Reviews (Last Twelve Months)')
plt.title('Top 5 Neighborhoods Dengan Jumlah Review Terbanyak 12 bulan terakhir')
plt.show()

# %% [markdown]
# > Jumlah Review berdasarkan Room type dan neighbourhood

# %%
# Create a pivot table
pivot_table = pd.pivot_table(
    data, values='number_of_reviews_ltm', 
    index=['neighbourhood'], 
    columns=['room_type'], 
    aggfunc=np.sum, 
    fill_value=0)

# Sum the values across room types to get total reviews for each neighborhood
pivot_table['Total'] = pivot_table.sum(axis=1)

# Get the top 5 neighborhoods based on total reviews
top_region_data = pivot_table.sort_values(by='Total', ascending=False).head(5)

top_region_data
# Out:
# room_type      Entire home/apt  Hotel room  Private room  Shared room  Total
# neighbourhood
# Khlong Toei              12422         190           986            3  13601
# Vadhana                   8692         144           831           42   9709
# Ratchathewi               3289         187           946           33   4455
# Bang Rak                  2602         127           679           12   3420
# Sathon                    2863          10           349           10   3232

# %%
# Filter the original data for the top 5 regions
top_region_data = data[data['neighbourhood'].isin(top_region_data.index)]

# Get the order of regions based on the total reviews in descending order
order_regions = top_region_data.groupby('neighbourhood')['number_of_reviews_ltm'].sum().sort_values(ascending=False).index

# Get the order of room types based on the total reviews within each neighbourhood
order_room_types = top_region_data.groupby(['neighbourhood', 'room_type'])['number_of_reviews_ltm'].sum().unstack().sum(axis=0).sort_values(ascending=False).index

# Plotting
plt.figure(figsize=(12, 5))
ax = sns.barplot(
    data=top_region_data.sort_values(['neighbourhood', 'room_type']),
    x='neighbourhood', y='number_of_reviews_ltm', hue='room_type',
    estimator=sum, linewidth=0, order=order_regions, hue_order=order_room_types  
)

# Manually remove the lines above the bars
for line in ax.lines:
    line.set_visible(False)

plt.title('Jumlah Review Berdasarkan Room Type berdasarkan Top 5 Neighbourhood')

# Adding review count label above each bar
for p in ax.patches:
    height = p.get_height()
    if height > 0:
        ax.text(p.get_x() + p.get_width() / 2., height + 5, f'{int(height)}', ha='center', va='bottom')

plt.xlabel('neighbourhood')
plt.ylabel('Jumlah Review (12 Bulan Terakhir)')
plt.legend(title='Room Type')

plt.show()

# %% [markdown]
# Lingkungan Khlong Toei:
#
# Jenis kamar yang paling populer adalah "Seluruh rumah/apartemen" dengan 12.422 ulasan.
# Ada juga jumlah ulasan yang signifikan untuk "Kamar pribadi" (986 ulasan).
# "Kamar hotel" dan "Kamar bersama" memiliki jumlah ulasan yang relatif lebih rendah.
# Lingkungan Vadhana:
#
# Mirip dengan Khlong Toei, "Seluruh rumah/apartemen" adalah jenis kamar paling populer dengan 8.692 ulasan.
# "Kamar pribadi" merupakan jenis kamar kedua yang paling banyak dipesan dengan 831 ulasan.
# "Kamar hotel" dan "Kamar bersama" memiliki jumlah ulasan yang lebih sedikit dibandingkan dengan dua jenis lainnya.
# Lingkungan Ratchathewi:
#
# "Seluruh rumah/apartemen" adalah jenis kamar yang paling banyak dipesan dengan 3.289 ulasan.
# "Kamar pribadi" dan "Kamar hotel" memiliki jumlah ulasan yang serupa, sementara "Kamar bersama" memiliki jumlah yang lebih rendah.
# Lingkungan Bang Rak:
#
# "Seluruh rumah/apartemen" adalah jenis kamar yang paling populer dengan 2.602 ulasan.
# "Kamar pribadi" dan "Kamar hotel" mengikuti dengan jumlah ulasan yang lebih sedikit, sementara "Kamar bersama" memiliki jumlah ulasan terendah.
# Lingkungan Sathon:
#
# "Seluruh rumah/apartemen" adalah jenis kamar yang dominan dengan 2.863 ulasan.
# "Kamar pribadi" dan "Kamar hotel" memiliki jumlah yang mencolok, sementara "Kamar bersama" memiliki jumlah ulasan terendah.

# %% [markdown]
# > Jumlah Review berdasarkan Room type dan region

# %%
# Create a pivot table
pivot_table = pd.pivot_table(
    data, values='number_of_reviews_ltm', 
    index=['region'], 
    columns=['room_type'], 
    aggfunc=np.sum, 
    fill_value=0)

# Sum the values across room types to get total reviews for each neighborhood
pivot_table['Total'] = pivot_table.sum(axis=1)

# Get the top 5 neighborhoods based on total reviews
top_region_data = pivot_table.sort_values(by='Total', ascending=False).head(5)

top_region_data
# Out:
# room_type        Entire home/apt  Hotel room  Private room  Shared room  Total
# region
# South Bangkok              30609         592          3874           79  35154
# Central Bangkok             9744         373          3502          128  13747
# North Bangkok               1764           3           737            1   2505
# North Thonburi              1464          19           570            6   2059
# East Bangkok                 639         271           432            4   1346

# %%
# Filter the original data for the top 5 regions
top_region_data = data[data['region'].isin(top_region_data.index)]

# Get the order of regions based on the total reviews in descending order
order_regions = top_region_data.groupby('region')['number_of_reviews_ltm'].sum().sort_values(ascending=False).index

# Get the order of room types based on the total reviews within each region
order_room_types = top_region_data.groupby(['region', 'room_type'])['number_of_reviews_ltm'].sum().unstack().sum(axis=0).sort_values(ascending=False).index

# Plotting
plt.figure(figsize=(12, 5))
ax = sns.barplot(
    data=top_region_data.sort_values(['region', 'room_type']),
    x='region', y='number_of_reviews_ltm', hue='room_type',
    estimator=sum, linewidth=0, order=order_regions, hue_order=order_room_types  # Set order based on the sorted regions and room types
)

# Manually remove the lines above the bars
for line in ax.lines:
    line.set_visible(False)

plt.title('Jumlah Review 12 bulan terakhir berdasarkan Region dan Room Type')

# Adding review count label above each bar
for p in ax.patches:
    height = p.get_height()
    if height > 0:
        ax.text(p.get_x() + p.get_width() / 2., height + 5, f'{int(height)}', ha='center', va='bottom')

plt.xlabel('Region')
plt.ylabel('Number of Reviews (Last Twelve Months)')
plt.legend(title='Room Type')

plt.show()

# %% [markdown]
# Wilayah South Bangkok:
#
# Jenis kamar yang paling populer adalah "Entire Home/apartemen" dengan 30.609 ulasan.
# Terdapat juga jumlah ulasan yang signifikan untuk "Kamar pribadi" (3.874 ulasan).
# "Kamar hotel" dan "Kamar bersama" memiliki jumlah ulasan yang relatif lebih rendah.
# Wilayah Central Bangkok:
#
# "Seluruh rumah/apartemen" merupakan jenis kamar yang paling banyak dipesan dengan 9.744 ulasan.
# "Kamar pribadi" adalah jenis kamar kedua yang paling populer dengan 3.502 ulasan.
# "Kamar hotel" dan "Kamar bersama" memiliki jumlah ulasan yang lebih rendah.
# Wilayah North Bangkok:
#
# "Seluruh rumah/apartemen" adalah jenis kamar yang paling banyak dipesan dengan 1.764 ulasan.
# "Kamar pribadi" dan "Kamar hotel" memiliki jumlah ulasan yang cukup, sementara "Kamar bersama" memiliki jumlah yang lebih rendah.
# Wilayah North Thonburi:
#
# "Seluruh rumah/apartemen" adalah jenis kamar yang dominan dengan 1.464 ulasan.
# "Kamar pribadi" dan "Kamar hotel" juga memiliki jumlah ulasan yang cukup, sementara "Kamar bersama" memiliki jumlah ulasan yang lebih rendah.
# Wilayah East Bangkok:
#
# "Seluruh rumah/apartemen" adalah jenis kamar yang paling banyak dipesan dengan 639 ulasan.
# "Kamar hotel" memiliki jumlah ulasan yang cukup, sementara "Kamar pribadi" juga cukup populer.
# "Kamar bersama" memiliki jumlah ulasan yang lebih rendah.

# %% [markdown]
# ### **Analisa berdasarkan `last_review` (Terakhir Mendapatkan Review)**

# %% [markdown]
# > last review berdasarkan tahun

# %%
# Membuat Kolom Baru Berdasarkan Tahun Terakhir Mendapatkan Review
dt_last_review['Year']= dt_last_review['last_review'].apply(lambda x : str(x)[:4])
dt_last_review.head()
# Out:
#         id                                            name  host_id host_name  \
# 0    27934                 Nice room with superb city view   120437    Nuttee
# 3    35780  Spacious one bedroom at The Kris Condo Bldg. 3   153730   Sirilak
# 5  1704776                  NEw Pro!!  Bungalow Bkk Centre  2129668  Wimonpak
# 6    48736                 Condo with Chaopraya River View   222005  Athitaya
# 8  1744248              Batcave, Pool view, near Chatuchak  9181769       Nol
#
#    neighbourhood  latitude  longitude        room_type  price  minimum_nights  \
# 0    Ratchathewi  13.75983  100.54134  Entire home/apt   1905               3
# 3      Din Daeng  13.78823  100.57256     Private room   1286               7
# 5  Bang Kho laen  13.69757  100.52880  Entire home/apt   1000             250
# 6     Rat Burana  13.68556  100.49535     Private room   1558               3
# 8     Chatu Chak  13.81693  100.56433  Entire home/apt   1558               3
#
# ...

# %%
# Membuat DataFrame dengan mengelompokan kolom 'Year' dan menghitung jumlah baris berdasarkan nilai 'Year'
dt_year = dt_last_review.groupby('Year').count().sort_values('Year',ascending=False).reset_index()[['Year', 'id']]

# Membuat Kolom baru untuk mengetahui persentase pertahunnya
dt_year['id'].sum()
dt_year['persentase'] = dt_year['id'] / dt_year['id'].sum() * 100

print('menghitung jumlah baris berdasarkan nilai Year')
dt_year
# Out:
# menghitung jumlah baris berdasarkan nilai Year
#     Year    id  persentase
# 0   2022  6628   65.871596
# 1   2021   207    2.057245
# 2   2020  1248   12.403101
# 3   2019  1012   10.057643
# 4   2018   484    4.810177
# 5   2017   267    2.653548
# 6   2016   149    1.480819
# 7   2015    50    0.496919
# 8   2014     9    0.089445
# 9   2013     7    0.069569
# 10  2012     1    0.009938

# %%
tahun = dt_year['Year']
jumlah = dt_year['id']

# Memvisualisasikan Review terakhir yang didapat listing berdasarkan Tahunnya
plt.figure(figsize=(15, 6))
ax = sns.lineplot(data=dt_year.sort_values('Year'), x='Year', y='id', marker='o')
plt.title('Review Terakhir yang Diperoleh per Listing (2012 - 2022)', size=16)
plt.xticks(ticks=tahun, rotation=45)

plt.xlabel('Tahun')
plt.ylabel('Frekuensi Review')
plt.grid(True)

# Menambahkan label pada setiap titik data tahun
for i, txt in enumerate(jumlah):
    ax.annotate(txt, (tahun[i], jumlah[i]), textcoords="offset points", xytext=(0, 5), ha='center')

plt.show()

# %% [markdown]
# ### Insight :
# - Jumlah listing yang mendapat review terakhir yang paling banyak adalah pada **Tahun 2022**
# - Distribusi yang Tidak Merata: Distribusi review tidak merata di seluruh tahun, dengan periode 2012-2015 memiliki kontribusi yang lebih rendah.
# - Stabilitas di Tahun-tahun Sebelumnya: Tahun 2018-2021 menunjukkan stabilitas jumlah review, mencerminkan performa listing yang konsisten.
# - Perhatian terhadap 2020 dan 2021: Pengurangan review pada 2021 mungkin mencerminkan dampak pandemi COVID-19 dan perubahan perilaku konsumen.

# %% [markdown]
# > bulan

# %%
# Mapping numeric month values to their corresponding names
month_name_mapping = {
    '01': 'Jan', '02': 'Feb', '03': 'Mar', '04': 'Apr',
    '05': 'May', '06': 'Jun', '07': 'Jul', '08': 'Aug',
    '09': 'Sep', '10': 'Oct', '11': 'Nov', '12': 'Dec'
}

# Extracting month from the 'last_review' column and mapping to non-numeric representations
dt_last_review['Month'] = dt_last_review['last_review'].apply(lambda x: month_name_mapping.get(str(x)[5:7]))

# Group by 'Month' and count the number of rows for each month
dt_month = dt_last_review.groupby('Month').count().reset_index()[['Month', 'id']]

# Calculate the total count of rows
total_reviews_month = dt_month['id'].sum()

# Create a new column 'percentage' to store the percentage for each month
dt_month['percentage'] = (dt_month['id'] / total_reviews_month) * 100

# %%
# Define the custom order of months
custom_month_order = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']

# Convert 'Month' column to categorical with the custom order
dt_month['Month'] = pd.Categorical(dt_month['Month'], categories=custom_month_order, ordered=True)

# Sort the DataFrame based on the custom order of months
dt_month_sorted = dt_month.sort_values('Month')

# Display the sorted DataFrame
print('jumlah baris berdasarkan nilai month')
dt_month_sorted
# Out:
# jumlah baris berdasarkan nilai month
#    Month    id  percentage
# 4    Jan   628    6.241304
# 3    Feb   537    5.336911
# 7    Mar   520    5.167959
# 0    Apr   310    3.080898
# 8    May   235    2.335520
# 6    Jun   267    2.653548
# 5    Jul   393    3.905784
# 1    Aug   474    4.710793
# 11   Sep   530    5.267342
# 10   Oct   722    7.175512
# 9    Nov  1711   17.004572
# 2    Dec  3735   37.119857

# %%
bulan = dt_month['Month']
jumlah_bulan = dt_month['id']

# Sortir DataFrame berdasarkan 'Month' secara ascending
dt_month_sorted = dt_month.sort_values('Month')

# Memvisualisasikan Review terakhir yang didapat listing berdasarkan Bulannya
plt.figure(figsize=(15, 6))
ax = sns.lineplot(data=dt_month_sorted, x='Month', y='id', marker='o')
plt.title('Review Terakhir yang Diperoleh per Listing (Bulan)', size=16)
plt.xticks(ticks=bulan, rotation=45)
plt.xlabel('Bulan')
plt.ylabel('Frekuensi')

# Menambahkan label pada setiap titik data bulan
for i, txt in enumerate(jumlah_bulan):
    ax.annotate(txt, (bulan[i], jumlah_bulan[i]), textcoords="offset points", xytext=(0, 10), ha='center')

plt.show()

# %% [markdown]
# Insight :
#
# - Desember (Dec) memiliki jumlah review tertinggi:
#   Bulan Desember memiliki jumlah review tertinggi dengan 3,735, yang mencapai sekitar 37.12% dari total review selama periode yang diamati. Ini menunjukkan bahwa Desember mungkin menjadi bulan dengan aktivitas pemesanan dan pengunjung yang tinggi.
#
# - November (Nov) juga memiliki kontribusi signifikan:
#   Bulan November menyusul dengan jumlah review sebanyak 1,711 atau sekitar 17% dari total. Ini menunjukkan bahwa November juga merupakan bulan yang penting dalam hal aktivitas pengguna.
#
# - Peningkatan aktivitas pada musim liburan:
#
#   Bulan Desember dan November, yang masuk dalam musim liburan dan liburan akhir tahun, menunjukkan peningkatan signifikan dalam jumlah review. Ini dapat dihubungkan dengan meningkatnya permintaan akomodasi selama liburan dan perayaan akhir tahun.

# %% [markdown]
# > region yang sudah/belum mendapat review

# %%
# Membuat DataFrame untuk properti yang sudah pernah mendapat review berdasarkan region
reviewed_properties_by_region = data[data['number_of_reviews'] > 0].groupby('region')['number_of_reviews'].count().reset_index()

# Membuat DataFrame untuk properti yang belum pernah mendapat review berdasarkan region
unreviewed_properties_by_region = data[data['number_of_reviews'] == 0].groupby('region')['number_of_reviews'].count().reset_index()

# %%
# Menggabungkan data untuk mendapatkan total properti
total_properties_by_region = data.groupby('region')['number_of_reviews'].count().reset_index().rename(columns={'number_of_reviews': 'number_of_reviews_total'})

# Menggabungkan data untuk mendapatkan persentase
merged_data_with_percentage = pd.merge(reviewed_properties_by_region, unreviewed_properties_by_region, on='region', how='outer', suffixes=('_reviewed', '_unreviewed'))
merged_data_with_percentage = pd.merge(merged_data_with_percentage, total_properties_by_region, on='region', how='outer')

# Menghitung persentase properti yang sudah dan belum mendapat review
merged_data_with_percentage['percentage_reviewed'] = (merged_data_with_percentage['number_of_reviews_reviewed'] / merged_data_with_percentage['number_of_reviews_total']) * 100
merged_data_with_percentage['percentage_unreviewed'] = (merged_data_with_percentage['number_of_reviews_unreviewed'] / merged_data_with_percentage['number_of_reviews_total']) * 100

# Mengubah format persentase menjadi seperti yang diminta
merged_data_with_percentage['percentage_reviewed'] = merged_data_with_percentage['percentage_reviewed'].apply(lambda x: f'{x:.1f}%')
merged_data_with_percentage['percentage_unreviewed'] = merged_data_with_percentage['percentage_unreviewed'].apply(lambda x: f'{x:.1f}%')

# Menampilkan hasil
print('Data Properti dengan Persentase Berdasarkan Region:')
print(merged_data_with_percentage[['region', 'number_of_reviews_reviewed', 'number_of_reviews_unreviewed', 'percentage_reviewed', 'percentage_unreviewed']])
# Out:
# Data Properti dengan Persentase Berdasarkan Region:
#             region  number_of_reviews_reviewed  number_of_reviews_unreviewed  \
# 0  Central Bangkok                        2678                          1472
# 1     East Bangkok                         384                           442
# 2    North Bangkok                         695                           609
# 3   North Thonburi                         628                           505
# 4    South Bangkok                        5503                          2571
# 5   South Thonburi                         174                           184
#
#   percentage_reviewed percentage_unreviewed
# 0               64.5%                 35.5%
# 1               46.5%                 53.5%
# 2               53.3%                 46.7%
# 3               55.4%                 44.6%
# 4               68.2%                 31.8%
# 5               48.6%                 51.4%

# %% [markdown]
# - Central Bangkok memiliki properti paling banyak:
#   Jumlah properti yang sudah mendapat review di Central Bangkok cukup tinggi, mencapai 2678.
#   Namun, masih ada sekitar 1472 properti di Central Bangkok yang belum mendapat review.
#
# - Variasi Jumlah Properti di Setiap Region:
#   South Bangkok memiliki jumlah properti yang sudah mendapat review paling tinggi (5503), sementara East Bangkok memiliki jumlah yang lebih rendah (384).
#   Meskipun jumlah properti yang sudah mendapat review di South Bangkok tinggi, tetapi masih ada 2571 properti di sana yang belum mendapat review.

# %%
# Menggabungkan data untuk mendapatkan total properti
total_properties_by_region = data.groupby('region')['number_of_reviews'].count().reset_index().rename(columns={'number_of_reviews': 'number_of_reviews_total'})

# Menggabungkan data untuk mendapatkan persentase
merged_data_with_percentage = pd.merge(reviewed_properties_by_region, unreviewed_properties_by_region, on='region', how='outer', suffixes=('_reviewed', '_unreviewed'))
merged_data_with_percentage = pd.merge(merged_data_with_percentage, total_properties_by_region, on='region', how='outer')

# Menghitung persentase properti yang sudah dan belum mendapat review
merged_data_with_percentage['percentage_reviewed'] = (merged_data_with_percentage['number_of_reviews_reviewed'] / merged_data_with_percentage['number_of_reviews_total']) * 100
merged_data_with_percentage['percentage_unreviewed'] = (merged_data_with_percentage['number_of_reviews_unreviewed'] / merged_data_with_percentage['number_of_reviews_total']) * 100

# Membuat bar plot
plt.figure(figsize=(15, 8))

# Menentukan lebar setiap bar
bar_width = 0.35

# Menghitung posisi x untuk setiap grup
x_reviewed = np.arange(len(merged_data_with_percentage.head(10)))
x_unreviewed = x_reviewed + bar_width

# Membuat bar plot untuk persentase properti yang sudah mendapat review
plt.bar(x_reviewed, merged_data_with_percentage.sort_values(by='number_of_reviews_reviewed', ascending=False)['percentage_reviewed'], color='blue', width=bar_width, label='Sudah Mendapat Review')

# Membuat bar plot untuk persentase properti yang belum mendapat review
plt.bar(x_unreviewed, merged_data_with_percentage.sort_values(by='number_of_reviews_reviewed', ascending=False)['percentage_unreviewed'], color='red', width=bar_width, label='Belum Mendapat Review')

# Menambahkan label di atas setiap bar
for i, value in enumerate(merged_data_with_percentage.sort_values(by='number_of_reviews_reviewed', ascending=False)['percentage_reviewed']):
    plt.text(i, value + 1, f'{value:.1f}%', ha='center', va='bottom', color='blue')

for i, value in enumerate(merged_data_with_percentage.sort_values(by='number_of_reviews_reviewed', ascending=False)['percentage_unreviewed']):
    plt.text(i + bar_width, value + 1, f'{value:.1f}%', ha='center', va='bottom', color='red')

# Menambahkan label region di bawah setiap grup
plt.xticks(np.arange(len(merged_data_with_percentage.head(10))) + bar_width / 2, merged_data_with_percentage.sort_values(by='number_of_reviews_reviewed', ascending=False)['region'], rotation=45)

# Menambahkan label pada plot
plt.title('Perbandingan Jumlah Properti yang Sudah dan Belum Mendapat Review Berdasarkan Region')
plt.xlabel('Region')
plt.ylabel('Persentase Jumlah Properti')
plt.legend()

# Menampilkan plot
plt.show()

# %% [markdown]
# > neighbourhood yang sudah/belum mendapat review

# %%
# Membuat DataFrame untuk properti yang sudah pernah mendapat review berdasarkan neighbourhood
reviewed_properties_by_neighbourhood = data[data['number_of_reviews'] > 0].groupby('neighbourhood')['number_of_reviews'].count().reset_index()

# Membuat DataFrame untuk properti yang belum pernah mendapat review berdasarkan neighbourhood
unreviewed_properties_by_neighbourhood = data[data['number_of_reviews'] == 0].groupby('neighbourhood')['number_of_reviews'].count().reset_index()

# %%
# Menggabungkan data untuk mendapatkan total properti
total_properties_by_neighbourhood = data.groupby('neighbourhood')['number_of_reviews'].count().reset_index().rename(columns={'number_of_reviews': 'number_of_reviews_total'})

# Menggabungkan data untuk mendapatkan persentase
merged_data_with_percentage_neighbourhood = pd.merge(reviewed_properties_by_neighbourhood, unreviewed_properties_by_neighbourhood, on='neighbourhood', how='outer', suffixes=('_reviewed', '_unreviewed'))
merged_data_with_percentage_neighbourhood = pd.merge(merged_data_with_percentage_neighbourhood, total_properties_by_neighbourhood, on='neighbourhood', how='outer')

# Menghitung persentase properti yang sudah dan belum mendapat review
merged_data_with_percentage_neighbourhood['percentage_reviewed'] = (merged_data_with_percentage_neighbourhood['number_of_reviews_reviewed'] / merged_data_with_percentage_neighbourhood['number_of_reviews_total']) * 100
merged_data_with_percentage_neighbourhood['percentage_unreviewed'] = (merged_data_with_percentage_neighbourhood['number_of_reviews_unreviewed'] / merged_data_with_percentage_neighbourhood['number_of_reviews_total']) * 100

# Merubah persentase menjadi format dengan satu desimal dan tanda persen
merged_data_with_percentage_neighbourhood['percentage_reviewed'] = merged_data_with_percentage_neighbourhood['percentage_reviewed'].map('{:.1f}%'.format)
merged_data_with_percentage_neighbourhood['percentage_unreviewed'] = merged_data_with_percentage_neighbourhood['percentage_unreviewed'].map('{:.1f}%'.format)

# Drop kolom 'number_of_reviews_total'
merged_data_with_percentage_neighbourhood = merged_data_with_percentage_neighbourhood.drop('number_of_reviews_total', axis=1)

# Menampilkan DataFrame dengan persentase yang telah diubah formatnya
print(merged_data_with_percentage_neighbourhood.sort_values(by='number_of_reviews_reviewed', ascending=False).head())
# Out:
#    neighbourhood  number_of_reviews_reviewed  number_of_reviews_unreviewed  \
# 22   Khlong Toei                        1620                           477
# 47       Vadhana                        1398                           752
# 37   Ratchathewi                         771                           342
# 18   Huai Khwang                         736                           389
# 8       Bang Rak                         586                           241
#
#    percentage_reviewed percentage_unreviewed
# 22               77.3%                 22.7%
# 47               65.0%                 35.0%
# 37               69.3%                 30.7%
# 18               65.4%                 34.6%
# 8                70.9%                 29.1%

# %%
# Menggabungkan data untuk plot
merged_data = pd.merge(reviewed_properties_by_neighbourhood, unreviewed_properties_by_neighbourhood, on='neighbourhood', how='outer', suffixes=('_reviewed', '_unreviewed'))

# Membuat bar plot
plt.figure(figsize=(15, 8))
ax = sns.barplot(data=merged_data.sort_values(by='number_of_reviews_reviewed', ascending=False).head(5), x='neighbourhood', y='number_of_reviews_reviewed', color='blue', label='Sudah Mendapat Review')
sns.barplot(data=merged_data.sort_values(by='number_of_reviews_reviewed', ascending=False).head(5), x='neighbourhood', y='number_of_reviews_unreviewed', color='red', label='Belum Mendapat Review')

# Menambahkan label di atas setiap bar
for p in ax.patches:
    height = p.get_height()
    ax.text(p.get_x() + p.get_width() / 2., height + 5, f'{int(height)}', ha='center', va='bottom')

# Menambahkan label pada plot
plt.title('Perbandingan Jumlah Properti yang Sudah dan Belum Mendapat Review Berdasarkan neighbourhood')
plt.xlabel('Neighbourhood')
plt.ylabel('Jumlah Properti')
plt.legend()

# Menampilkan plot
plt.show()

# %% [markdown]
# > jumlah review by room type : Entire home/apt

# %%
top_properties_apt = data.groupby(['name', 'neighbourhood', 'room_type'])['number_of_reviews'].sum().reset_index()
top_properties_apt= top_properties_apt.sort_values(by='number_of_reviews', ascending=False)

# Filter for 'Entire home/apt'
top_properties_entire_home = top_properties_apt[top_properties_apt['room_type'] == 'Entire home/apt'].head(5)

# Display the top properties
print('Jumlah review berdasarkan room type')
top_properties_entire_home
# Out:
# Jumlah review berdasarkan room type
#                                                    name neighbourhood  \
# 3155      Beautiful One Bedroom Apartment Near Skytrain    Phaya Thai
# 1490  30days!  Sukhumvit NANA spacious 1BR 2PPL near...   Ratchathewi
# 1492  30days! AirportLink Sukhumvit NANA MaxValu 2BR...   Ratchathewi
# 1552      37 Nature House: 10 mins to DMK Int'l Airport        Lak Si
# 993   2 Mins walk BTS. 4pp walk Siam, MBK,CTW,WaterGate   Ratchathewi
#
#             room_type  number_of_reviews
# 3155  Entire home/apt               1224
# 1490  Entire home/apt                955
# 1492  Entire home/apt                811
# 1552  Entire home/apt                533
# 993   Entire home/apt                491

# %%
# Membuat bar chart
plt.figure(figsize=(12, 8))
ax = sns.barplot(x='number_of_reviews', y='name', hue='neighbourhood', data=top_properties_entire_home, palette='viridis')

# Menambahkan count labels di atas setiap bar
for p in ax.patches:
    if p.get_width() != 0:
        plt.annotate(str(int(p.get_width())), (p.get_width(), p.get_y() + p.get_height() / 2.), ha='left', va='center', xytext=(5, 0), textcoords='offset points')

# Add labels
plt.title('Top 5 Properties Entire Home/apt dengan Jumlah Ulasan Terbanyak berdasarkan Neighbourhood')
plt.xlabel('Jumlah Ulasan')
plt.ylabel('Property Name')

# Display the plot
plt.show()

# %% [markdown]
# > room type : Hotel

# %%
top_properties_htl = data.groupby(['name', 'neighbourhood', 'room_type'])['number_of_reviews'].sum().reset_index()
top_properties_htl= top_properties_htl.sort_values(by='number_of_reviews', ascending=False)

# Filter for 'Entire home/apt'
top_properties_htl = top_properties_htl[top_properties_htl['room_type'] == 'Hotel room'].head(5)

# Display the top properties
print('top 5 properti hotel berdassarkan jumlah review dan neighbourhood')
top_properties_htl
# Out:
# top 5 properti hotel berdassarkan jumlah review dan neighbourhood
#                                        name neighbourhood   room_type  \
# 12218       The Mustang Nero/No.4 The Horse   Khlong Toei  Hotel room
# 12217        The Mustang Nero/No.3 The Wolf   Khlong Toei  Hotel room
# 12221  The Mustang Nero/No.7 The Zebra Song   Khlong Toei  Hotel room
# 12216      The Mustang Nero/No.2 Black Bird   Khlong Toei  Hotel room
# 12214    The Mustang Nero/No.1 Magic Dragon   Khlong Toei  Hotel room
#
#        number_of_reviews
# 12218                486
# 12217                477
# 12221                433
# 12216                426
# 12214                393

# %%
# Membuat bar chart
plt.figure(figsize=(12, 8))
ax = sns.barplot(x='number_of_reviews', y='name', hue='neighbourhood', data=top_properties_htl, palette='viridis')

# Menambahkan count labels di atas setiap bar
for p in ax.patches:
    if p.get_width() != 0:
        plt.annotate(str(int(p.get_width())), (p.get_width(), p.get_y() + p.get_height() / 2.), ha='left', va='center', xytext=(5, 0), textcoords='offset points')

# Add labels
plt.title('Top 5 Properties Hotel dengan Jumlah Ulasan Terbanyak berdasarkan Neighbourhood')
plt.xlabel('Jumlah Ulasan')
plt.ylabel('Property Name')

# Display the plot
plt.show()

# %% [markdown]
# berdasarkan jumlah ulasan dan kecamatan (neighbourhood), menunjukkan dominasi The Mustang Nero di Khlong Toei. dan keempat lainnya juga menunjukan  popularitas tinggi The Mustang Nero di Khlong Toei, memberikan gambaran tentang keunggulan dan daya tarik propertinya yang konsisten.

# %% [markdown]
# > Room type : Private Room

# %%
data['room_type'].unique()
# Out:
# array(['Entire home/apt', 'Private room', 'Hotel room', 'Shared room'],
#       dtype=object)

# %%
top_properties_pvt = data.groupby(['name', 'neighbourhood', 'room_type'])['number_of_reviews'].sum().reset_index()
top_properties_pvt= top_properties_pvt.sort_values(by='number_of_reviews', ascending=False)

# Filter for 'Entire home/apt'
top_properties_pvt = top_properties_pvt[top_properties_pvt['room_type'] == 'Private room'].head(5)

# Display the top properties
print('top 5 properti private room berdasarkan jumlah review dan neighbourhood')
top_properties_pvt
# Out:
# top 5 properti private room berdasarkan jumlah review dan neighbourhood
#                                                     name  \
# 5690   FREE PICK UP⭐BKK AIRPORT/BREAKFAST/PRIVATE DELUXE
# 13368         near DMK: Don Mueang International Airport
# 2778                 Ba hao Residence x MAITRI CHIT ROOM
# 9728   Private Cozy Room (Free Breakfast) 20 mins to DMK
# 2779                   Ba hao Residence x SANTIPHAP ROOM
#
#               neighbourhood     room_type  number_of_reviews
# 5690            Lat Krabang  Private room                807
# 13368            Don Mueang  Private room                451
# 2778   Pom Prap Sattru Phai  Private room                402
# 9728             Chatu Chak  Private room                348
# 2779   Pom Prap Sattru Phai  Private room                330

# %%
# Membuat bar chart
plt.figure(figsize=(12, 8))
ax = sns.barplot(x='number_of_reviews', y='name', hue='neighbourhood', data=top_properties_pvt, palette='viridis')

# Menambahkan count labels di atas setiap bar
for p in ax.patches:
    if p.get_width() != 0:
        plt.annotate(str(int(p.get_width())), (p.get_width(), p.get_y() + p.get_height() / 2.), ha='left', va='center', xytext=(5, 0), textcoords='offset points')

# Add labels
plt.title('Top 5 Properties Private room dengan Jumlah Ulasan Terbanyak berdasarkan Neighbourhood')
plt.xlabel('Jumlah Ulasan')
plt.ylabel('Property Name')

# Display the plot
plt.show()

# %% [markdown]
# > room type : Shared room

# %%
top_properties_shrd = data.groupby(['name', 'neighbourhood', 'room_type'])['number_of_reviews'].sum().reset_index()
top_properties_shrd= top_properties_shrd.sort_values(by='number_of_reviews', ascending=False)

# Filter for 'Entire home/apt'
top_properties_shrd = top_properties_shrd[top_properties_shrd['room_type'] == 'Shared room'].head(5)

# Display the top properties
print('top 5 properti shared room berdasarkan jumlah review dan neighbourhood')
top_properties_shrd
# Out:
# top 5 properti shared room berdasarkan jumlah review dan neighbourhood
#                                                     name neighbourhood  \
# 7108   Lamurr Sukhumvit41 near BTS @ center of Bangkok 3       Vadhana
# 12734                                          VM1hostel    Phaya Thai
# 6079                    Good Day 8 Bunk Beds Dorm room A   Ratchathewi
# 3649                         Bunk bed in Mixed Dormitory   Phra Nakhon
# 6292   HOFT Hostel 5 Mins from BTS : 1-Bed in Mixed Dorm      Bang Rak
#
#          room_type  number_of_reviews
# 7108   Shared room                153
# 12734  Shared room                139
# 6079   Shared room                105
# 3649   Shared room                103
# 6292   Shared room                 93

# %%
# Membuat bar chart
plt.figure(figsize=(12, 8))
ax = sns.barplot(x='number_of_reviews', y='name', hue='neighbourhood', data=top_properties_shrd, palette='viridis')

# Menambahkan count labels di atas setiap bar
for p in ax.patches:
    if p.get_width() != 0:
        plt.annotate(str(int(p.get_width())), (p.get_width(), p.get_y() + p.get_height() / 2.), ha='left', va='center', xytext=(5, 0), textcoords='offset points')

# Add labels
plt.title('Top 5 Properties Private room dengan Jumlah Ulasan Terbanyak berdasarkan Neighbourhood')
plt.xlabel('Jumlah Ulasan')
plt.ylabel('Property Name')

# Display the plot
plt.show()

# %% [markdown]
# ## Kesimpulan
#
# 1. South Bangkok Dominan: Wilayah South Bangkok menonjol dengan jumlah properti dan aktivitas tertinggi, khususnya dalam tipe kamar "Entire home/apt". Ini menunjukkan tingginya minat dan permintaan di wilayah tersebut, mungkin disebabkan oleh keberagaman dan popularitasnya sebagai tujuan wisata atau tempat tinggal.
#
# 2. Central Bangkok Tertinggi di Hotel Room: Central Bangkok memiliki jumlah hotel room yang signifikan, mencerminkan adanya preferensi atau kebutuhan akan fasilitas hotel di pusat kota. Total properti di Central Bangkok juga cukup tinggi.
#
# 3. North Bangkok dan North Thonburi Menengah: Wilayah North Bangkok dan North Thonburi memiliki jumlah properti yang cukup, meskipun lebih rendah dibandingkan dengan South dan Central Bangkok. North Bangkok memiliki jumlah properti "Entire home/apt" yang signifikan, sedangkan North Thonburi menunjukkan variasi yang cukup baik.
#
# 4. East Bangkok dengan Pilihan Menengah: East Bangkok menunjukkan jumlah properti yang lebih rendah, tetapi masih menyediakan beragam jenis kamar. Hotel room cukup populer di wilayah ini.

# %% [markdown]
# 1. Jumlah Listing per Region:
#    South Bangkok memiliki jumlah listing tertinggi dengan 8,074, diikuti oleh Central Bangkok dengan 4,150.
#    South Thonburi memiliki jumlah listing terendah dengan 358.
#
# 2. Neighborhood dengan Jumlah Listing Tertinggi:
#    Vadhana dan Khlong Toei menjadi neighborhood dengan jumlah listing tertinggi, masing-masing dengan 2,150 dan 2,097.
#
# 3. Room Type dan Harga:
#    Mayoritas listing adalah Entire home/apt dengan harga rata-rata **1,514**, diikuti oleh Hotel room dengan harga rata-rata **1,481**.
#
# 4. Harga Berdasarkan Region dan Room Type:
#    Central Bangkok memiliki harga tertinggi untuk Entire home/apt **(1,514)** dan Hotel room **(1,481)**.
#    East Bangkok memiliki harga tertinggi untuk Private room **(899.5)**.
#    South Bangkok memiliki harga tertinggi untuk Shared room **(494.5)**.
#
# 5. Room Type Berdasarkan Jumlah Review:
#    Entire home/apt memiliki jumlah review tertinggi (197,943), diikuti oleh Private room (50,703), Hotel room (12,700), dan Shared room (2,682).
#
# 6. Jumlah Review 12 Bulan Terakhir Berdasarkan Region:
#    South Bangkok dan Central Bangkok memiliki jumlah review tertinggi dalam 12 bulan terakhir, masing-masing dengan 35,154 dan 13,747.

# %% [markdown]
# ## Rekomendasi
#
# 1. Kerjasama dengan Pemilik Properti untuk Penyesuaian Fitur:
#    menjalin kerjasama yang erat dengan pemilik properti. Kolaborasi ini dapat membantu dalam penyesuaian fitur properti agar sesuai dengan harapan penyewa. direkomendasikan untuk mengembangkan pengalaman penyewa melalui penawaran layanan tambahan. Pengembangan paket dan fasilitas unik dapat memberikan nilai tambah dan meningkatkan kepuasan penyewa.
#
# 2. Implementasi Strategi Pemasaran Berbasis Wilayah:
#    Agar dapat merespon perbedaan preferensi di berbagai wilayah, sangat disarankan untuk menerapkan strategi pemasaran yang dioptimalkan khusus untuk setiap wilayah. Dalam hal ini, personalisasi pemasaran menjadi kunci untuk meningkatkan daya tarik properti di mata penyewa potensial.
#
#    - South Bangkok :
#      Menampilkan keindahan pantai, sungai, dan suasana yang lebih tenang dengan gambar-gambar yang menyoroti alam sekitar.
#
#    - Central Bangkok:
#      menampilkan kehidupan malam yang sibuk, pusat perbelanjaan mewah, dan kehidupan perkotaan yang dinamis, mencerminkan kemewahan dan   kecanggihan pusat bisnis Bangkok. gaya hidup perkotaan yang dinamis dan fasilitas eksklusif.
#
#    - North Bangkok:
#      Menyoroti keberadaan pusat bisnis lokal, taman hijau, dan kemudahan akses ke fasilitas pendidikan dan menekankan kemudahan akses ke pusat kota atau keuntungan lingkungan perumahan yang lebih hijau.
#
#    - East Bangkok:
#      Menekankan kemudahan akses ke pusat perbelanjaan atau area bisnis di timur. Mungkin menargetkan kelompok yang mencari kehidupan perkotaan yang aktif.
#
#    - North Thonburi:
#      Menyoroti keunikan dan daya tarik khusus dari bagian ini, mungkin kebudayaan lokal atau kegiatan yang spesifik untuk wilayah ini dan keberadaan bangunan bersejarah, pasar tradisional, dan fasilitas transportasi air di sekitar properti.
#
#    - South Thonburi:
#      menekankan keindahan alam, keberagaman kuliner, kemudahan akses ke pusat kota melalui jembatan atau transportasi air. Mungkin menargetkan kelompok yang mencari alternatif kehidupan perkotaan yang sedikit lebih tenang.
#
# 3. Penyesuaian Harga Berdasarkan Lokasi:
#    Lakukan penyesuaian strategi harga berdasarkan karakteristik masing-masing region di Bangkok. Pertimbangkan menetapkan harga yang lebih tinggi di Central Bangkok, mengingat statusnya sebagai pusat bisnis dan kebudayaan. Sementara itu, dalam wilayah South Bangkok, East Bangkok, North Thonburi, dan South Thonburi, pertimbangkan untuk menawarkan harga yang lebih terjangkau guna meningkatkan daya tarik penyewa.
#
# 4. Properti yang kurang menonjol :
#    - melakukan beberapa promosi yang dilakukan seperti meningkatkan fasilitas yang ada pada room type dan melakukan promosi untuk meningkatkan pengalaman penyewa dengan menawarkan paket dan fasilitas tambahan yang unik, seperti tur lokal atau layanan tambahan.
#
# 5. Penawaran Khusus untuk Wilayah Tertentu:
#     Menawarkan promosi khusus atau diskon untuk properti di wilayah tertentu dengan pertumbuhan ulasan yang potensial.
